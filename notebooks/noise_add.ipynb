# %%
import numpy as np
import pandas as pd
import random

# %%
train = pd.read_csv('/opt/ml/dataset/train/train.csv')

# %%
subjt=train['subject_entity'].apply(lambda x: pd.Series(eval(x))).add_prefix('subj_')
objt=train['object_entity'].apply(lambda x: pd.Series(eval(x))).add_prefix('obj_')
full_train = pd.concat([train[['id','sentence','label','source']],subjt,objt],axis=1)

# %%
objt['obj_type'].unique()
# Out:
# array(['PER', 'ORG', 'DAT', 'LOC', 'POH', 'NOH'], dtype=object)

# %%
full_train[full_train['label']=='no_relation']
# Out:
#           id                                           sentence        label  \
# 0      10795  〈Something〉는 조지 해리슨이 쓰고 비틀즈가 1969년 앨범 《Abbey R...  no_relation
# 1      21557  호남이 기반인 바른미래당·대안신당·민주평화당이 우여곡절 끝에 합당해 민생당(가칭)으...  no_relation
# 4       7319  1967년 프로 야구 드래프트 1순위로 요미우리 자이언츠에게 입단하면서 등번호는 8...  no_relation
# 6      19063  그에 따라 나폴리와 계약을 연장한 마라도나는 1989년 팀을 UEFA컵 정상으로 인...  no_relation
# 14     26410  조토 디 본도네, 마사초, 피에로 델라 프란체스카, 도메니코 기를란다요, 페루지노,...  no_relation
# ...      ...                                                ...          ...
# 32457  29234  21일 정읍시에 따르면 올해 노후 경유차 조기 폐차 지원사업으로 예산 17억6880...  no_relation
# 32459  22174  메이저 리그 10승 경력을 높이 사서, 2011년 12월 2일 삼성 라이온즈에 영입...  no_relation
# 32460   3358  위광환 전라남도 해양수산국장은 “지난 3차례 스마트양식 클러스터 조성 공모를 통해 ...  no_relation
# 32462   4572  심지어 전용 연습구장도 없어 훈련을 여러 지역을 돌아다니며 해야 할 정도로 팀 사정...  no_relation
# 32468   3648  중앙일보, JTBC 회장을 지낸 이후 중앙홀딩스 회장, 재단법인 한반도평화만들기 이...  no_relation
#
#           source  subj_word  subj_start_idx  subj_end_idx subj_type obj_word  \
# 0      wikipedia        비틀즈              24            26       ORG   조지 해리슨
# 1       wikitree      민주평화당              19            23       ORG     대안신당
# 4      wikipedia  요미우리 자이언츠              22            30       ORG     1967
# 6      wikipedia      AC 밀란              64            68       ORG     1989
# 14     wikipedia      미켈란젤로              47            51       PER     르네상스
# ...          ...        ...             ...           ...       ...      ...
# 32457   wikitree        정읍시               4             6       ORG    1100대
# 32459  wikipedia    삼성 라이온즈              35            41       ORG    2011년
# 32460   wikitree        영광군              72            74       ORG     전라남도
# 32462  wikipedia        방승환              85            87       PER      공격수
# 32468  wikipedia       JTBC               6             9       ORG    중앙홀딩스
#
#        obj_start_idx  obj_end_idx obj_type
# 0                 13           18      PER
# 1                 14           17      ORG
# 4                  0            3      DAT
# 6                 25           28      DAT
# 14                96           99      DAT
# ...              ...          ...      ...
# 32457             61           65      NOH
# 32459             22           26      DAT
# 32460              4            7      LOC
# 32462             94           96      POH
# 32468             21           25      ORG
#
# [9534 rows x 12 columns]

# %%
random.seed(42)

# %%
random.shuffle(full_train['id'].values)

# %%
full_train
# Out:
#           id                                           sentence  \
# 0      10795  〈Something〉는 조지 해리슨이 쓰고 비틀즈가 1969년 앨범 《Abbey R...
# 1      21557  호남이 기반인 바른미래당·대안신당·민주평화당이 우여곡절 끝에 합당해 민생당(가칭)으...
# 2        360  K리그2에서 성적 1위를 달리고 있는 광주FC는 지난 26일 한국프로축구연맹으로부터...
# 3      24861  균일가 생활용품점 (주)아성다이소(대표 박정부)는 코로나19 바이러스로 어려움을 겪...
# 4       7319  1967년 프로 야구 드래프트 1순위로 요미우리 자이언츠에게 입단하면서 등번호는 8...
# ...      ...                                                ...
# 32465   9012  한국당은 7일 오전 9시부터 오후 5시까지 진행된 원내대표 및 정책위의장 후보자 등...
# 32466  24299  법포는 다시 최시형, 서병학, 손병희 직계인 북접과 다시 서장옥, 전봉준, 김개남을...
# 32467    819  완도군(군수 신우철)이 국토교통부에서 실시한 '2019 교통문화지수 실태조사'에서 ...
# 32468   3648  중앙일보, JTBC 회장을 지낸 이후 중앙홀딩스 회장, 재단법인 한반도평화만들기 이...
# 32469  20952  화순군(군수 구충곤)은 17일 동면의 이장 20여 명이 코로나 19 예방을 위해 버...
#
#                            label     source  subj_word  subj_start_idx  \
# 0                    no_relation  wikipedia        비틀즈              24
# 1                    no_relation   wikitree      민주평화당              19
# 2                  org:member_of   wikitree       광주FC              21
# 3      org:top_members/employees   wikitree      아성다이소              13
# 4                    no_relation  wikipedia  요미우리 자이언츠              22
# ...                          ...        ...        ...             ...
# 32465            per:employee_of   wikitree        유기준              93
# 32466             per:colleagues  wikipedia        최시형               7
# 32467  org:top_members/employees   wikitree        완도군               0
# 32468                no_relation  wikipedia       JTBC               6
# 32469  org:top_members/employees   wikitree        화순군               0
#
#        subj_end_idx subj_type  obj_word  obj_start_idx  obj_end_idx obj_type
# 0                26       ORG    조지 해리슨             13           18      PER
# 1                23       ORG      대안신당             14           17      ORG
# 2                24       ORG  한국프로축구연맹             34           41      ORG
# 3                17       ORG       박정부             22           24      PER
# 4                30       ORG      1967              0            3      DAT
# ...             ...       ...       ...            ...          ...      ...
# 32465            95       PER  부산 서구·동구            100          107      LOC
# 32466             9       PER       손병희             17           19      PER
# 32467             2       ORG       신우철              7            9      PER
# 32468             9       ORG     중앙홀딩스             21           25      ORG
# 32469             2       ORG       구충곤              7            9      PER
#
# [32470 rows x 12 columns]

# %%
subjt.iloc[train['id'],0]
# Out:
# 0              비틀즈
# 1            민주평화당
# 2             광주FC
# 3            아성다이소
# 4        요미우리 자이언츠
#            ...
# 32465          유기준
# 32466          최시형
# 32467          완도군
# 32468         JTBC
# 32469          화순군
# Name: subj_word, Length: 32470, dtype: object

# %%
def noise_data(dataset):
    subjt=dataset['subject_entity'].apply(lambda x: pd.Series(eval(x))).add_prefix('subj_')
    objt=dataset['object_entity'].apply(lambda x: pd.Series(eval(x))).add_prefix('obj_')
    dataset['rnd_id']=dataset['id']
    random.shuffle(dataset['rnd_id'].values)
    rnd_subjWord=subjt.iloc[dataset['rnd_id'],0]
    rnd_objWord =objt.iloc[dataset['rnd_id'],0]
    temp = dataset['sentence']
    return rnd_subjWord, rnd_objWord

# %%
subj,obj = noise_data(train)

# %%
obj
# Out:
# 6516          더콰이엇
# 32008         포병대장
# 10424          이중근
# 31456          김범수
# 30467          박상렬
#            ...
# 6822     로만 아브라모비치
# 26424        탈인상주의
# 16289          배국환
# 757            김대중
# 8023          불가리아
# Name: obj_word, Length: 32470, dtype: object

# %%
train
# Out:
#           id                                           sentence  \
# 0          0  〈Something〉는 조지 해리슨이 쓰고 비틀즈가 1969년 앨범 《Abbey R...
# 1          1  호남이 기반인 바른미래당·대안신당·민주평화당이 우여곡절 끝에 합당해 민생당(가칭)으...
# 2          2  K리그2에서 성적 1위를 달리고 있는 광주FC는 지난 26일 한국프로축구연맹으로부터...
# 3          3  균일가 생활용품점 (주)아성다이소(대표 박정부)는 코로나19 바이러스로 어려움을 겪...
# 4          4  1967년 프로 야구 드래프트 1순위로 요미우리 자이언츠에게 입단하면서 등번호는 8...
# ...      ...                                                ...
# 32465  32465  한국당은 7일 오전 9시부터 오후 5시까지 진행된 원내대표 및 정책위의장 후보자 등...
# 32466  32466  법포는 다시 최시형, 서병학, 손병희 직계인 북접과 다시 서장옥, 전봉준, 김개남을...
# 32467  32467  완도군(군수 신우철)이 국토교통부에서 실시한 '2019 교통문화지수 실태조사'에서 ...
# 32468  32468  중앙일보, JTBC 회장을 지낸 이후 중앙홀딩스 회장, 재단법인 한반도평화만들기 이...
# 32469  32469  화순군(군수 구충곤)은 17일 동면의 이장 20여 명이 코로나 19 예방을 위해 버...
#
#                                           subject_entity  \
# 0      {'word': '비틀즈', 'start_idx': 24, 'end_idx': 26...
# 1      {'word': '민주평화당', 'start_idx': 19, 'end_idx': ...
# 2      {'word': '광주FC', 'start_idx': 21, 'end_idx': 2...
# 3      {'word': '아성다이소', 'start_idx': 13, 'end_idx': ...
# 4      {'word': '요미우리 자이언츠', 'start_idx': 22, 'end_id...
# ...                                                  ...
# 32465  {'word': '유기준', 'start_idx': 93, 'end_idx': 95...
# 32466  {'word': '최시형', 'start_idx': 7, 'end_idx': 9, ...
# 32467  {'word': '완도군', 'start_idx': 0, 'end_idx': 2, ...
# 32468  {'word': 'JTBC', 'start_idx': 6, 'end_idx': 9,...
# 32469  {'word': '화순군', 'start_idx': 0, 'end_idx': 2, ...
#
#                                            object_entity  \
# 0      {'word': '조지 해리슨', 'start_idx': 13, 'end_idx':...
# 1      {'word': '대안신당', 'start_idx': 14, 'end_idx': 1...
# 2      {'word': '한국프로축구연맹', 'start_idx': 34, 'end_idx...
# 3      {'word': '박정부', 'start_idx': 22, 'end_idx': 24...
# 4      {'word': '1967', 'start_idx': 0, 'end_idx': 3,...
# ...                                                  ...
# 32465  {'word': '부산 서구·동구', 'start_idx': 100, 'end_id...
# 32466  {'word': '손병희', 'start_idx': 17, 'end_idx': 19...
# 32467  {'word': '신우철', 'start_idx': 7, 'end_idx': 9, ...
# 32468  {'word': '중앙홀딩스', 'start_idx': 21, 'end_idx': ...
# 32469  {'word': '구충곤', 'start_idx': 7, 'end_idx': 9, ...
#
#                            label     source  rnd_id
# 0                    no_relation  wikipedia    6516
# 1                    no_relation   wikitree   32008
# 2                  org:member_of   wikitree   10424
# 3      org:top_members/employees   wikitree   31456
# 4                    no_relation  wikipedia   30467
# ...                          ...        ...     ...
# 32465            per:employee_of   wikitree    6822
# 32466             per:colleagues  wikipedia   26424
# 32467  org:top_members/employees   wikitree   16289
# 32468                no_relation  wikipedia     757
# 32469  org:top_members/employees   wikitree    8023
#
# [32470 rows x 7 columns]

# %%
def unzip_entity(dataset):
    subjt=dataset['subject_entity'].apply(lambda x: pd.Series(eval(x))).add_prefix('subj_')
    objt=dataset['object_entity'].apply(lambda x: pd.Series(eval(x))).add_prefix('obj_')
    out_dataset = pd.concat([dataset[['id','sentence','label','source']],subjt,objt],axis=1)
    return out_dataset

def noise_data(dataset):
    subjt=dataset['subject_entity'].apply(lambda x: pd.Series(eval(x))).add_prefix('subj_')
    objt=dataset['object_entity'].apply(lambda x: pd.Series(eval(x))).add_prefix('obj_')
    dataset['rnd_id']=dataset['id']
    random.shuffle(dataset['rnd_id'].values)
    rnd_subjWord=subjt.iloc[dataset['rnd_id'],0]
    rnd_objWord =objt.iloc[dataset['rnd_id'],0]
    dataset.drop(columns='rnd_id',inplace=True)
    return rnd_subjWord, rnd_objWord

# 필요한 column들만 뽑아서 쓸 수 있게 간단하게 작성
def column_selion(dataset, columns):
  out_columns = dataset.loc[:,columns]
  return out_columns

# special token을 포함한 단일 문장 분류 sentence 만들기 위한 전초 작업, 이후 change sentence로 원 문장 변경
def make_sentence1(dataset):
    subj_entity = []
    obj_entity = [] 
    for i in range(len(dataset)):
        e01 = ''.join(['<subj>',dataset.loc[i]['subj_word'],'</subj>'])
        e02 = ''.join(['<obj>',dataset.loc[i]['obj_word'],'</obj>'])
        subj_entity.append(e01)
        obj_entity.append(e02)
    return subj_entity, obj_entity

# token1 column, token2 column을 받아서 여러개의 column을 사용해 sentence1을 만들수 있게 customize
def make_sentence2(dataset,token1_column,token2_column):
    concat_entity = []
    for i in range(len(dataset)):
        temp = ''
        e01 = ' '.join(dataset.loc[i,token1_column].values)
        e02 = ' '.join(dataset.loc[i,token2_column].values)
        temp = e01 + ' [SEP] ' + e02
        concat_entity.append(temp)
    return concat_entity, list(dataset['sentence'])


# subj word와 obj word를 바꾸고 그 내용을 원 문장과 다른 column들에 반영할 수 있게 만든 method
# 다만 동일 길이의 list를 넣어줘야 함.
def change_sentence(dataset,subj_word_list,obj_word_list):
    subjt=dataset['subject_entity'].apply(lambda x: pd.Series(eval(x))).add_prefix('subj_')
    objt=dataset['object_entity'].apply(lambda x: pd.Series(eval(x))).add_prefix('obj_')
    concat_dataset = pd.concat([dataset[['id','sentence','label','source']],subjt,objt],axis=1)
    sentence = []
    subj_entity =[]
    obj_entity = []
    label = []
    for (i, d), s, o in zip(concat_dataset.iterrows(),subj_word_list,obj_word_list):   
        subj_dict = {}
        obj_dict = {}
        subj_dict['word'] = s
        obj_dict['word'] = o
        if d['subj_start_idx'] < d['obj_start_idx']:
            subj_dict['start_idx'] = d['subj_start_idx']
            subj_dict['end_idx'] = d['subj_end_idx'] + len(s) - len(d['subj_word'])
            obj_dict['start_idx'] = d['obj_start_idx'] + len(s) - len(d['subj_word'])
            obj_dict['end_idx'] = d['obj_end_idx'] + len(o)-len(d['subj_word'])+len(s) - len(d['obj_word'])
        else:
            obj_dict['start_idx'] = d['obj_start_idx']
            obj_dict['end_idx'] = d['obj_end_idx'] + len(o) - len(d['obj_word'])
            subj_dict['start_idx'] = d['subj_start_idx'] + len(o) - len(d['obj_word'])
            subj_dict['end_idx'] = d['subj_end_idx'] + len(s)-len(d['subj_word'])+len(o) - len(d['obj_word'])
        temp = ''
        temp = d['sentence'][:d['subj_start_idx']]+d['sentence'][d['subj_start_idx']:].replace(d['subj_word'],s,1)
        sentence.append(temp[:d['obj_start_idx']]+temp[d['obj_start_idx']:].replace(d['obj_word'],o,1))
        subj_dict['type'] =None
        obj_dict['type'] =None
        subj_entity.append(str(subj_dict))
        obj_entity.append(str(obj_dict))
        label.append('no_relation')
    out_dataset = pd.DataFrame({'id':concat_dataset['id'],'sentence':sentence,\
        'subject_entity':subj_entity,'object_entity':obj_entity,
        'label':label,'source':concat_dataset['source']})
    return out_dataset

# %%
subj, obj =noise_data(train)

# %%
subj
# Out:
# 27989         칭화 대학
# 19707       전라남도체육회
# 21059           ISO
# 14661           김현성
# 20855    제15특수임무비행단
#             ...
# 19664          영온옹주
# 11282         마이크로닷
# 17661       레알 마드리드
# 6324           f(x)
# 29050        서울 이랜드
# Name: subj_word, Length: 32470, dtype: object

# %%
obj
# Out:
# 27989           베이징
# 19707         전남체육회
# 21059     국제 표준화 기구
# 14661          대한민국
# 20855          서울공항
#             ...
# 19664         숙의 박씨
# 11282          뉴질랜드
# 17661    산티아고 베르나베우
# 6324           에프엑스
# 29050           정정용
# Name: obj_word, Length: 32470, dtype: object

# %%
ch_train = change_sentence(train,obj,subj)

# %%
train.head(10)
# Out:
#    id                                           sentence  \
# 0   0  〈Something〉는 조지 해리슨이 쓰고 비틀즈가 1969년 앨범 《Abbey R...
# 1   1  호남이 기반인 바른미래당·대안신당·민주평화당이 우여곡절 끝에 합당해 민생당(가칭)으...
# 2   2  K리그2에서 성적 1위를 달리고 있는 광주FC는 지난 26일 한국프로축구연맹으로부터...
# 3   3  균일가 생활용품점 (주)아성다이소(대표 박정부)는 코로나19 바이러스로 어려움을 겪...
# 4   4  1967년 프로 야구 드래프트 1순위로 요미우리 자이언츠에게 입단하면서 등번호는 8...
# 5   5  : 유엔, 유럽 의회, 북대서양 조약 기구 (NATO), 국제이주기구, 세계 보건 ...
# 6   6  그에 따라 나폴리와 계약을 연장한 마라도나는 1989년 팀을 UEFA컵 정상으로 인...
# 7   7  박용오(朴容旿, 1937년 4월 29일(음력 3월 19일)(음력 3월 19일) ~ ...
# 8   8  중공군에게 온전히 대항할 수 없을 정도로 약해진 국민당은 타이베이로 수도를 옮기는 ...
# 9   9  특히 김동연 전 경제부총리를 비롯한 김두관 국회의원, 안규백 국회의원, 김종민 국회...
#
#                                       subject_entity  \
# 0  {'word': '비틀즈', 'start_idx': 24, 'end_idx': 26...
# 1  {'word': '민주평화당', 'start_idx': 19, 'end_idx': ...
# 2  {'word': '광주FC', 'start_idx': 21, 'end_idx': 2...
# 3  {'word': '아성다이소', 'start_idx': 13, 'end_idx': ...
# 4  {'word': '요미우리 자이언츠', 'start_idx': 22, 'end_id...
# 5  {'word': '북대서양 조약 기구', 'start_idx': 13, 'end_i...
# 6  {'word': 'AC 밀란', 'start_idx': 64, 'end_idx': ...
# 7  {'word': '박용오', 'start_idx': 0, 'end_idx': 2, ...
# 8  {'word': '중화민국', 'start_idx': 59, 'end_idx': 6...
# 9  {'word': '안규백', 'start_idx': 30, 'end_idx': 32...
#
#                                        object_entity  \
# 0  {'word': '조지 해리슨', 'start_idx': 13, 'end_idx':...
# 1  {'word': '대안신당', 'start_idx': 14, 'end_idx': 1...
# 2  {'word': '한국프로축구연맹', 'start_idx': 34, 'end_idx...
# 3  {'word': '박정부', 'start_idx': 22, 'end_idx': 24...
# 4  {'word': '1967', 'start_idx': 0, 'end_idx': 3,...
# 5  {'word': 'NATO', 'start_idx': 25, 'end_idx': 2...
# 6  {'word': '1989', 'start_idx': 25, 'end_idx': 2...
# 7  {'word': '1937년 4월 29일', 'start_idx': 9, 'end_...
# 8  {'word': '타이베이', 'start_idx': 32, 'end_idx': 3...
# 9  {'word': '더불어민주당', 'start_idx': 100, 'end_idx'...
#
#                        label     source
# 0                no_relation  wikipedia
# 1                no_relation   wikitree
# 2              org:member_of   wikitree
# 3  org:top_members/employees   wikitree
# 4                no_relation  wikipedia
# 5        org:alternate_names  wikipedia
# 6                no_relation  wikipedia
# 7          per:date_of_birth  wikipedia
# 8  org:place_of_headquarters  wikipedia
# 9            per:employee_of   wikitree

# %%
ch_train.head(10)
# Out:
#    id                                           sentence  \
# 0   0  〈Something〉는 칭화 대학이 쓰고 베이징가 1969년 앨범 《Abbey Ro...
# 1   1  호남이 기반인 바른미래당·전라남도체육회·전남체육회이 우여곡절 끝에 합당해 민생당(가...
# 2   2  K리그2에서 성적 1위를 달리고 있는 국제 표준화 기구는 지난 26일 ISO으로부터...
# 3   3  균일가 생활용품점 (주)대한민국(대표 박정부)는 코로나19 바이러스로 어려움을 겪고...
# 4   4  제15특수임무비행단년 프로 야구 드래프트 1순위로 서울공항에게 입단하면서 등번호는 ...
# 5   5  : 유엔, 유럽 의회, 캐나다 (NATO), 국제이주기구, 세계 보건 기구 (WHO...
# 6   6  그에 따라 나폴리와 계약을 연장한 마라도나는 명성왕후년 팀을 UEFA컵 정상으로 인...
# 7   7  타예레스(朴容旿, 하비에르 파스토레(음력 3월 19일)(음력 3월 19일) ~ 20...
# 8   8  중공군에게 온전히 대항할 수 없을 정도로 약해진 국민당은 안유진로 수도를 옮기는 것...
# 9   9  특히 김동연 전 경제부총리를 비롯한 김두관 국회의원, 정의개발당 국회의원, 김종민 ...
#
#                                       subject_entity  \
# 0  {'word': '베이징', 'start_idx': 23, 'end_idx': 25...
# 1  {'word': '전남체육회', 'start_idx': 22, 'end_idx': ...
# 2  {'word': '국제 표준화 기구', 'start_idx': 21, 'end_id...
# 3  {'word': '대한민국', 'start_idx': 13, 'end_idx': 1...
# 4  {'word': '서울공항', 'start_idx': 28, 'end_idx': 3...
# 5  {'word': '캐나다', 'start_idx': 13, 'end_idx': 15...
# 6  {'word': '인경왕후', 'start_idx': 64, 'end_idx': 6...
# 7  {'word': '타예레스', 'start_idx': 0, 'end_idx': 3,...
# 8  {'word': '스타쉽엔터테인먼트', 'start_idx': 58, 'end_id...
# 9  {'word': '정의개발당', 'start_idx': 30, 'end_idx': ...
#
#                                        object_entity        label     source
# 0  {'word': '칭화 대학', 'start_idx': 13, 'end_idx': ...  no_relation  wikipedia
# 1  {'word': '전라남도체육회', 'start_idx': 14, 'end_idx'...  no_relation   wikitree
# 2  {'word': 'ISO', 'start_idx': 39, 'end_idx': 41...  no_relation   wikitree
# 3  {'word': '김현성', 'start_idx': 21, 'end_idx': 23...  no_relation   wikitree
# 4  {'word': '제15특수임무비행단', 'start_idx': 0, 'end_id...  no_relation  wikipedia
# 5  {'word': '캐서린 위닉', 'start_idx': 18, 'end_idx':...  no_relation  wikipedia
# 6  {'word': '명성왕후', 'start_idx': 25, 'end_idx': 2...  no_relation  wikipedia
# 7  {'word': '하비에르 파스토레', 'start_idx': 10, 'end_id...  no_relation  wikipedia
# 8  {'word': '안유진', 'start_idx': 32, 'end_idx': 34...  no_relation  wikipedia
# 9  {'word': '레제프 타이이프 에르도안', 'start_idx': 102, 'e...  no_relation   wikitree

# %%
chs_train =  change_sentence(train,obj,list(map(lambda x: eval(x)['word'],train['subject_entity'])))

# %%
cho_train =  change_sentence(train,list(map(lambda x: eval(x)['word'],train['object_entity'])),subj)

# %%
chs_train
# Out:
#           id                                           sentence  \
# 0          0  〈Something〉는 비틀즈이 쓰고 베이징가 1969년 앨범 《Abbey Road...
# 1          1  호남이 기반인 바른미래당·민주평화당·전남체육회이 우여곡절 끝에 합당해 민생당(가칭)...
# 2          2  K리그2에서 성적 1위를 달리고 있는 국제 표준화 기구는 지난 26일 광주FC으로부...
# 3          3  균일가 생활용품점 (주)대한민국(대표 박정부)는 코로나19 바이러스로 어려움을 겪고...
# 4          4  요미우리 자이언츠년 프로 야구 드래프트 1순위로 서울공항에게 입단하면서 등번호는 8...
# ...      ...                                                ...
# 32465  32465  한국당은 7일 오전 9시부터 오후 5시까지 진행된 원내대표 및 정책위의장 후보자 등...
# 32466  32466  법포는 다시 뉴질랜드, 서병학, 최시형 직계인 북접과 다시 서장옥, 전봉준, 김개남...
# 32467  32467  산티아고 베르나베우(군수 완도군)이 국토교통부에서 실시한 '2019 교통문화지수 실...
# 32468  32468  중앙일보, 에프엑스 회장을 지낸 이후 JTBC 회장, 재단법인 한반도평화만들기 이사...
# 32469  32469  정정용(군수 화순군)은 17일 동면의 이장 20여 명이 코로나 19 예방을 위해 버...
#
#                                           subject_entity  \
# 0      {'word': '베이징', 'start_idx': 21, 'end_idx': 23...
# 1      {'word': '전남체육회', 'start_idx': 20, 'end_idx': ...
# 2      {'word': '국제 표준화 기구', 'start_idx': 21, 'end_id...
# 3      {'word': '대한민국', 'start_idx': 13, 'end_idx': 1...
# 4      {'word': '서울공항', 'start_idx': 27, 'end_idx': 3...
# ...                                                  ...
# 32465  {'word': '숙의 박씨', 'start_idx': 93, 'end_idx': ...
# 32466  {'word': '뉴질랜드', 'start_idx': 7, 'end_idx': 10...
# 32467  {'word': '산티아고 베르나베우', 'start_idx': 0, 'end_id...
# 32468  {'word': '에프엑스', 'start_idx': 6, 'end_idx': 9,...
# 32469  {'word': '정정용', 'start_idx': 0, 'end_idx': 2, ...
#
#                                            object_entity        label  \
# 0      {'word': '비틀즈', 'start_idx': 13, 'end_idx': 15...  no_relation
# 1      {'word': '민주평화당', 'start_idx': 14, 'end_idx': ...  no_relation
# 2      {'word': '광주FC', 'start_idx': 39, 'end_idx': 4...  no_relation
# 3      {'word': '아성다이소', 'start_idx': 21, 'end_idx': ...  no_relation
# 4      {'word': '요미우리 자이언츠', 'start_idx': 0, 'end_idx...  no_relation
# ...                                                  ...          ...
# 32465  {'word': '유기준', 'start_idx': 102, 'end_idx': 1...  no_relation
# 32466  {'word': '최시형', 'start_idx': 18, 'end_idx': 20...  no_relation
# 32467  {'word': '완도군', 'start_idx': 14, 'end_idx': 16...  no_relation
# 32468  {'word': 'JTBC', 'start_idx': 21, 'end_idx': 2...  no_relation
# 32469  {'word': '화순군', 'start_idx': 7, 'end_idx': 9, ...  no_relation
#
#           source
# 0      wikipedia
# 1       wikitree
# 2       wikitree
# 3       wikitree
# 4      wikipedia
# ...          ...
# 32465   wikitree
# 32466  wikipedia
# 32467   wikitree
# 32468  wikipedia
# 32469   wikitree
#
# [32470 rows x 6 columns]

# %%
cho_train
# Out:
#           id                                           sentence  \
# 0          0  〈Something〉는 칭화 대학이 쓰고 조지 해리슨가 1969년 앨범 《Abbey...
# 1          1  호남이 기반인 바른미래당·전라남도체육회·대안신당이 우여곡절 끝에 합당해 민생당(가칭...
# 2          2  K리그2에서 성적 1위를 달리고 있는 한국프로축구연맹는 지난 26일 ISO으로부터 ...
# 3          3  균일가 생활용품점 (주)박정부(대표 박정부)는 코로나19 바이러스로 어려움을 겪고 ...
# 4          4  제15특수임무비행단년 프로 야구 드래프트 1순위로 1967에게 입단하면서 등번호는 ...
# ...      ...                                                ...
# 32465  32465  한국당은 7일 오전 9시부터 오후 5시까지 진행된 원내대표 및 정책위의장 후보자 등...
# 32466  32466  법포는 다시 손병희, 서병학, 마이크로닷 직계인 북접과 다시 서장옥, 전봉준, 김개...
# 32467  32467  신우철(군수 레알 마드리드)이 국토교통부에서 실시한 '2019 교통문화지수 실태조사...
# 32468  32468  중앙일보, 중앙홀딩스 회장을 지낸 이후 f(x) 회장, 재단법인 한반도평화만들기 이...
# 32469  32469  구충곤(군수 서울 이랜드)은 17일 동면의 이장 20여 명이 코로나 19 예방을 위...
#
#                                           subject_entity  \
# 0      {'word': '조지 해리슨', 'start_idx': 23, 'end_idx':...
# 1      {'word': '대안신당', 'start_idx': 22, 'end_idx': 2...
# 2      {'word': '한국프로축구연맹', 'start_idx': 21, 'end_idx...
# 3      {'word': '박정부', 'start_idx': 13, 'end_idx': 15...
# 4      {'word': '1967', 'start_idx': 28, 'end_idx': 3...
# ...                                                  ...
# 32465  {'word': '부산 서구·동구', 'start_idx': 93, 'end_idx...
# 32466  {'word': '손병희', 'start_idx': 7, 'end_idx': 9, ...
# 32467  {'word': '신우철', 'start_idx': 0, 'end_idx': 2, ...
# 32468  {'word': '중앙홀딩스', 'start_idx': 6, 'end_idx': 1...
# 32469  {'word': '구충곤', 'start_idx': 0, 'end_idx': 2, ...
#
#                                            object_entity        label  \
# 0      {'word': '칭화 대학', 'start_idx': 13, 'end_idx': ...  no_relation
# 1      {'word': '전라남도체육회', 'start_idx': 14, 'end_idx'...  no_relation
# 2      {'word': 'ISO', 'start_idx': 38, 'end_idx': 40...  no_relation
# 3      {'word': '김현성', 'start_idx': 20, 'end_idx': 22...  no_relation
# 4      {'word': '제15특수임무비행단', 'start_idx': 0, 'end_id...  no_relation
# ...                                                  ...          ...
# 32465  {'word': '영온옹주', 'start_idx': 105, 'end_idx': ...  no_relation
# 32466  {'word': '마이크로닷', 'start_idx': 17, 'end_idx': ...  no_relation
# 32467  {'word': '레알 마드리드', 'start_idx': 7, 'end_idx':...  no_relation
# 32468  {'word': 'f(x)', 'start_idx': 22, 'end_idx': 2...  no_relation
# 32469  {'word': '서울 이랜드', 'start_idx': 7, 'end_idx': ...  no_relation
#
#           source
# 0      wikipedia
# 1       wikitree
# 2       wikitree
# 3       wikitree
# 4      wikipedia
# ...          ...
# 32465   wikitree
# 32466  wikipedia
# 32467   wikitree
# 32468  wikipedia
# 32469   wikitree
#
# [32470 rows x 6 columns]

# %%
pd.concat([train,chs_train,cho_train],axis=0).drop(columns='id').reset_index(drop=True).reset_index().rename(columns={"index": "id"})
# Out:
#           id                                           sentence  \
# 0          0  〈Something〉는 조지 해리슨이 쓰고 비틀즈가 1969년 앨범 《Abbey R...
# 1          1  호남이 기반인 바른미래당·대안신당·민주평화당이 우여곡절 끝에 합당해 민생당(가칭)으...
# 2          2  K리그2에서 성적 1위를 달리고 있는 광주FC는 지난 26일 한국프로축구연맹으로부터...
# 3          3  균일가 생활용품점 (주)아성다이소(대표 박정부)는 코로나19 바이러스로 어려움을 겪...
# 4          4  1967년 프로 야구 드래프트 1순위로 요미우리 자이언츠에게 입단하면서 등번호는 8...
# ...      ...                                                ...
# 97405  97405  한국당은 7일 오전 9시부터 오후 5시까지 진행된 원내대표 및 정책위의장 후보자 등...
# 97406  97406  법포는 다시 손병희, 서병학, 마이크로닷 직계인 북접과 다시 서장옥, 전봉준, 김개...
# 97407  97407  신우철(군수 레알 마드리드)이 국토교통부에서 실시한 '2019 교통문화지수 실태조사...
# 97408  97408  중앙일보, 중앙홀딩스 회장을 지낸 이후 f(x) 회장, 재단법인 한반도평화만들기 이...
# 97409  97409  구충곤(군수 서울 이랜드)은 17일 동면의 이장 20여 명이 코로나 19 예방을 위...
#
#                                           subject_entity  \
# 0      {'word': '비틀즈', 'start_idx': 24, 'end_idx': 26...
# 1      {'word': '민주평화당', 'start_idx': 19, 'end_idx': ...
# 2      {'word': '광주FC', 'start_idx': 21, 'end_idx': 2...
# 3      {'word': '아성다이소', 'start_idx': 13, 'end_idx': ...
# 4      {'word': '요미우리 자이언츠', 'start_idx': 22, 'end_id...
# ...                                                  ...
# 97405  {'word': '부산 서구·동구', 'start_idx': 93, 'end_idx...
# 97406  {'word': '손병희', 'start_idx': 7, 'end_idx': 9, ...
# 97407  {'word': '신우철', 'start_idx': 0, 'end_idx': 2, ...
# 97408  {'word': '중앙홀딩스', 'start_idx': 6, 'end_idx': 1...
# 97409  {'word': '구충곤', 'start_idx': 0, 'end_idx': 2, ...
#
#                                            object_entity  \
# 0      {'word': '조지 해리슨', 'start_idx': 13, 'end_idx':...
# 1      {'word': '대안신당', 'start_idx': 14, 'end_idx': 1...
# 2      {'word': '한국프로축구연맹', 'start_idx': 34, 'end_idx...
# 3      {'word': '박정부', 'start_idx': 22, 'end_idx': 24...
# 4      {'word': '1967', 'start_idx': 0, 'end_idx': 3,...
# ...                                                  ...
# 97405  {'word': '영온옹주', 'start_idx': 105, 'end_idx': ...
# 97406  {'word': '마이크로닷', 'start_idx': 17, 'end_idx': ...
# 97407  {'word': '레알 마드리드', 'start_idx': 7, 'end_idx':...
# 97408  {'word': 'f(x)', 'start_idx': 22, 'end_idx': 2...
# 97409  {'word': '서울 이랜드', 'start_idx': 7, 'end_idx': ...
#
#                            label     source
# 0                    no_relation  wikipedia
# 1                    no_relation   wikitree
# 2                  org:member_of   wikitree
# 3      org:top_members/employees   wikitree
# 4                    no_relation  wikipedia
# ...                          ...        ...
# 97405                no_relation   wikitree
# 97406                no_relation  wikipedia
# 97407                no_relation   wikitree
# 97408                no_relation  wikipedia
# 97409                no_relation   wikitree
#
# [97410 rows x 6 columns]
