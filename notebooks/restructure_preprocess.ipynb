# %%
import pandas as pd

# %%
tr = pd.read_csv('../../../dataset/train/train.csv')
tr
# Out:
#           id                                           sentence  \
# 0          0  〈Something〉는 조지 해리슨이 쓰고 비틀즈가 1969년 앨범 《Abbey R...
# 1          1  호남이 기반인 바른미래당·대안신당·민주평화당이 우여곡절 끝에 합당해 민생당(가칭)으...
# 2          2  K리그2에서 성적 1위를 달리고 있는 광주FC는 지난 26일 한국프로축구연맹으로부터...
# 3          3  균일가 생활용품점 (주)아성다이소(대표 박정부)는 코로나19 바이러스로 어려움을 겪...
# 4          4  1967년 프로 야구 드래프트 1순위로 요미우리 자이언츠에게 입단하면서 등번호는 8...
# ...      ...                                                ...
# 32465  32465  한국당은 7일 오전 9시부터 오후 5시까지 진행된 원내대표 및 정책위의장 후보자 등...
# 32466  32466  법포는 다시 최시형, 서병학, 손병희 직계인 북접과 다시 서장옥, 전봉준, 김개남을...
# 32467  32467  완도군(군수 신우철)이 국토교통부에서 실시한 '2019 교통문화지수 실태조사'에서 ...
# 32468  32468  중앙일보, JTBC 회장을 지낸 이후 중앙홀딩스 회장, 재단법인 한반도평화만들기 이...
# 32469  32469  화순군(군수 구충곤)은 17일 동면의 이장 20여 명이 코로나 19 예방을 위해 버...
#
#                                           subject_entity  \
# 0      {'word': '비틀즈', 'start_idx': 24, 'end_idx': 26...
# 1      {'word': '민주평화당', 'start_idx': 19, 'end_idx': ...
# 2      {'word': '광주FC', 'start_idx': 21, 'end_idx': 2...
# 3      {'word': '아성다이소', 'start_idx': 13, 'end_idx': ...
# 4      {'word': '요미우리 자이언츠', 'start_idx': 22, 'end_id...
# ...                                                  ...
# 32465  {'word': '유기준', 'start_idx': 93, 'end_idx': 95...
# 32466  {'word': '최시형', 'start_idx': 7, 'end_idx': 9, ...
# 32467  {'word': '완도군', 'start_idx': 0, 'end_idx': 2, ...
# 32468  {'word': 'JTBC', 'start_idx': 6, 'end_idx': 9,...
# 32469  {'word': '화순군', 'start_idx': 0, 'end_idx': 2, ...
#
#                                            object_entity  \
# 0      {'word': '조지 해리슨', 'start_idx': 13, 'end_idx':...
# 1      {'word': '대안신당', 'start_idx': 14, 'end_idx': 1...
# 2      {'word': '한국프로축구연맹', 'start_idx': 34, 'end_idx...
# 3      {'word': '박정부', 'start_idx': 22, 'end_idx': 24...
# 4      {'word': '1967', 'start_idx': 0, 'end_idx': 3,...
# ...                                                  ...
# 32465  {'word': '부산 서구·동구', 'start_idx': 100, 'end_id...
# 32466  {'word': '손병희', 'start_idx': 17, 'end_idx': 19...
# 32467  {'word': '신우철', 'start_idx': 7, 'end_idx': 9, ...
# 32468  {'word': '중앙홀딩스', 'start_idx': 21, 'end_idx': ...
# 32469  {'word': '구충곤', 'start_idx': 7, 'end_idx': 9, ...
#
#                            label     source
# 0                    no_relation  wikipedia
# 1                    no_relation   wikitree
# 2                  org:member_of   wikitree
# 3      org:top_members/employees   wikitree
# 4                    no_relation  wikipedia
# ...                          ...        ...
# 32465            per:employee_of   wikitree
# 32466             per:colleagues  wikipedia
# 32467  org:top_members/employees   wikitree
# 32468                no_relation  wikipedia
# 32469  org:top_members/employees   wikitree
#
# [32470 rows x 6 columns]

# %%
def preprocessing_dataset(dataset):
  """ 처음 불러온 csv 파일을 원하는 형태의 DataFrame으로 변경 시켜줍니다."""
  subject_entity = []
  object_entity = []
  for i,j in zip(dataset['subject_entity'], dataset['object_entity']):
    i = i[1:-1].split(',')[0].split(':')[1]
    j = j[1:-1].split(',')[0].split(':')[1]

    subject_entity.append(i)
    object_entity.append(j)
  out_dataset = pd.DataFrame({'id':dataset['id'], 'sentence':dataset['sentence'],'subject_entity':subject_entity,'object_entity':object_entity,'label':dataset['label'],})
  return out_dataset

# %%
preprocessing_dataset(tr)
# Out:
#           id                                           sentence  \
# 0          0  〈Something〉는 조지 해리슨이 쓰고 비틀즈가 1969년 앨범 《Abbey R...
# 1          1  호남이 기반인 바른미래당·대안신당·민주평화당이 우여곡절 끝에 합당해 민생당(가칭)으...
# 2          2  K리그2에서 성적 1위를 달리고 있는 광주FC는 지난 26일 한국프로축구연맹으로부터...
# 3          3  균일가 생활용품점 (주)아성다이소(대표 박정부)는 코로나19 바이러스로 어려움을 겪...
# 4          4  1967년 프로 야구 드래프트 1순위로 요미우리 자이언츠에게 입단하면서 등번호는 8...
# ...      ...                                                ...
# 32465  32465  한국당은 7일 오전 9시부터 오후 5시까지 진행된 원내대표 및 정책위의장 후보자 등...
# 32466  32466  법포는 다시 최시형, 서병학, 손병희 직계인 북접과 다시 서장옥, 전봉준, 김개남을...
# 32467  32467  완도군(군수 신우철)이 국토교통부에서 실시한 '2019 교통문화지수 실태조사'에서 ...
# 32468  32468  중앙일보, JTBC 회장을 지낸 이후 중앙홀딩스 회장, 재단법인 한반도평화만들기 이...
# 32469  32469  화순군(군수 구충곤)은 17일 동면의 이장 20여 명이 코로나 19 예방을 위해 버...
#
#       subject_entity object_entity                      label
# 0              '비틀즈'      '조지 해리슨'                no_relation
# 1            '민주평화당'        '대안신당'                no_relation
# 2             '광주FC'    '한국프로축구연맹'              org:member_of
# 3            '아성다이소'         '박정부'  org:top_members/employees
# 4        '요미우리 자이언츠'        '1967'                no_relation
# ...              ...           ...                        ...
# 32465          '유기준'    '부산 서구·동구'            per:employee_of
# 32466          '최시형'         '손병희'             per:colleagues
# 32467          '완도군'         '신우철'  org:top_members/employees
# 32468         'JTBC'       '중앙홀딩스'                no_relation
# 32469          '화순군'         '구충곤'  org:top_members/employees
#
# [32470 rows x 5 columns]

# %%
tr.loc[:,['sentence','label']]
# Out:
#                                                 sentence  \
# 0      〈Something〉는 조지 해리슨이 쓰고 비틀즈가 1969년 앨범 《Abbey R...
# 1      호남이 기반인 바른미래당·대안신당·민주평화당이 우여곡절 끝에 합당해 민생당(가칭)으...
# 2      K리그2에서 성적 1위를 달리고 있는 광주FC는 지난 26일 한국프로축구연맹으로부터...
# 3      균일가 생활용품점 (주)아성다이소(대표 박정부)는 코로나19 바이러스로 어려움을 겪...
# 4      1967년 프로 야구 드래프트 1순위로 요미우리 자이언츠에게 입단하면서 등번호는 8...
# ...                                                  ...
# 32465  한국당은 7일 오전 9시부터 오후 5시까지 진행된 원내대표 및 정책위의장 후보자 등...
# 32466  법포는 다시 최시형, 서병학, 손병희 직계인 북접과 다시 서장옥, 전봉준, 김개남을...
# 32467  완도군(군수 신우철)이 국토교통부에서 실시한 '2019 교통문화지수 실태조사'에서 ...
# 32468  중앙일보, JTBC 회장을 지낸 이후 중앙홀딩스 회장, 재단법인 한반도평화만들기 이...
# 32469  화순군(군수 구충곤)은 17일 동면의 이장 20여 명이 코로나 19 예방을 위해 버...
#
#                            label
# 0                    no_relation
# 1                    no_relation
# 2                  org:member_of
# 3      org:top_members/employees
# 4                    no_relation
# ...                          ...
# 32465            per:employee_of
# 32466             per:colleagues
# 32467  org:top_members/employees
# 32468                no_relation
# 32469  org:top_members/employees
#
# [32470 rows x 2 columns]

# %%
def column_selection(dataset, columns):
  out_columns = dataset.loc[:,columns]
  return out_columns

# %%
tr.columns
# Out:
# Index(['id', 'sentence', 'subject_entity', 'object_entity', 'label', 'source'], dtype='object')

# %%
tr['sentence'].values
# Out:
# array(['〈Something〉는 조지 해리슨이 쓰고 비틀즈가 1969년 앨범 《Abbey Road》에 담은 노래다.',
#        '호남이 기반인 바른미래당·대안신당·민주평화당이 우여곡절 끝에 합당해 민생당(가칭)으로 재탄생한다.',
#        'K리그2에서 성적 1위를 달리고 있는 광주FC는 지난 26일 한국프로축구연맹으로부터 관중 유치 성과와 마케팅 성과를 인정받아 ‘풀 스타디움상’과 ‘플러스 스타디움상’을 수상했다.',
#        ...,
#        "완도군(군수 신우철)이 국토교통부에서 실시한 '2019 교통문화지수 실태조사'에서 229개 기초지자체 중 최상위 등급인 A등급을 받으면서 전국에서 가장 높은 교통안전 인식 수준을 갖고 있는 것으로 나타났다.",
#        '중앙일보, JTBC 회장을 지낸 이후 중앙홀딩스 회장, 재단법인 한반도평화만들기 이사장, 한국기원 총재를 맡고 있다.',
#        '화순군(군수 구충곤)은 17일 동면의 이장 20여 명이 코로나 19 예방을 위해 버스 승강장, 공중화장실 등 다중이용시설과 오동리 천운아파트 주변을 소독하는 방역 봉사활동을 펼쳤다고 밝혔다.'],
#       dtype=object)

# %%
tr['subject_entity'].values
# Out:
# array(["{'word': '비틀즈', 'start_idx': 24, 'end_idx': 26, 'type': 'ORG'}",
#        "{'word': '민주평화당', 'start_idx': 19, 'end_idx': 23, 'type': 'ORG'}",
#        "{'word': '광주FC', 'start_idx': 21, 'end_idx': 24, 'type': 'ORG'}",
#        ...,
#        "{'word': '완도군', 'start_idx': 0, 'end_idx': 2, 'type': 'ORG'}",
#        "{'word': 'JTBC', 'start_idx': 6, 'end_idx': 9, 'type': 'ORG'}",
#        "{'word': '화순군', 'start_idx': 0, 'end_idx': 2, 'type': 'ORG'}"],
#       dtype=object)

# %%
tr['object_entity'].values
# Out:
# array(["{'word': '조지 해리슨', 'start_idx': 13, 'end_idx': 18, 'type': 'PER'}",
#        "{'word': '대안신당', 'start_idx': 14, 'end_idx': 17, 'type': 'ORG'}",
#        "{'word': '한국프로축구연맹', 'start_idx': 34, 'end_idx': 41, 'type': 'ORG'}",
#        ...,
#        "{'word': '신우철', 'start_idx': 7, 'end_idx': 9, 'type': 'PER'}",
#        "{'word': '중앙홀딩스', 'start_idx': 21, 'end_idx': 25, 'type': 'ORG'}",
#        "{'word': '구충곤', 'start_idx': 7, 'end_idx': 9, 'type': 'PER'}"],
#       dtype=object)

# %%
eval(tr['subject_entity'][0]).items()
# Out:
# dict_items([('word', '비틀즈'), ('start_idx', 24), ('end_idx', 26), ('type', 'ORG')])

# %%
eval(tr['subject_entity'][0])['word']
# Out:
# '비틀즈'

# %%
tr.columns
# Out:
# Index(['id', 'sentence', 'subject_entity', 'object_entity', 'label', 'source'], dtype='object')

# %%
tr.iloc[0]['sentence']
# Out:
# '〈Something〉는 조지 해리슨이 쓰고 비틀즈가 1969년 앨범 《Abbey Road》에 담은 노래다.'

# %%
tr.loc[0]
# Out:
# id                                                                0
# sentence          〈Something〉는 조지 해리슨이 쓰고 비틀즈가 1969년 앨범 《Abbey R...
# subject_entity    {'word': '비틀즈', 'start_idx': 24, 'end_idx': 26...
# object_entity     {'word': '조지 해리슨', 'start_idx': 13, 'end_idx':...
# label                                                   no_relation
# source                                                    wikipedia
# Name: 0, dtype: object

# %%
def unzip_entity(dataset):
    subject_word = []
    subject_start_idx = []
    subject_end_idx = []
    subject_entity = []
    object_word = []
    object_start_idx = []
    object_end_idx = []
    object_entity = []
    for i, j in zip(dataset['subject_entity'],dataset['object_entity']):
        i = eval(i)
        j = eval(j)
        subject_word.append(i['word'])
        subject_start_idx.append(int(i['start_idx']))
        subject_end_idx.append(int(i['end_idx']))
        subject_entity.append(i['type'])
        object_word.append(j['word'])
        object_start_idx.append(int(j['start_idx']))
        object_end_idx.append(int(j['end_idx']))
        object_entity.append(j['type'])
    out_dataset = pd.DataFrame({'id':dataset['id'],'sentence':dataset['sentence'],\
        'subject_word':subject_word,'subject_start_idx':subject_start_idx,'subject_end_idx':subject_end_idx,'subject_entity':subject_entity,\
        'object_word':object_word,'object_start_idx':object_start_idx,'object_end_idx':object_end_idx,'object_entity':object_entity,\
        'label':dataset['label'],})
    return out_dataset

# %%
utr = unzip_entity(tr)

# %%
' '.join(tr.loc[0,['sentence','label']].values)
# Out:
# '〈Something〉는 조지 해리슨이 쓰고 비틀즈가 1969년 앨범 《Abbey Road》에 담은 노래다. no_relation'

# %%
def make_sentence1(dataset,token1_column,token2_column):
    concat_entity = []
    for i in range(len(dataset)):
        temp = ''
        e01 = ' '.join(dataset.loc[i,token1_column].values)
        e02 = ' '.join(dataset.loc[i,token2_column].values)
        temp = e01 + '[SEP]' + e02
        concat_entity.append(temp)
    return concat_entity

# %%
make_sentence1(utr,['subject_entity','subject_word'],['object_entity','object_word'])
# Out:
# ['ORG 비틀즈[SEP]PER 조지 해리슨',
#  'ORG 민주평화당[SEP]ORG 대안신당',
#  'ORG 광주FC[SEP]ORG 한국프로축구연맹',
#  'ORG 아성다이소[SEP]PER 박정부',
#  'ORG 요미우리 자이언츠[SEP]DAT 1967',
#  'ORG 북대서양 조약 기구[SEP]ORG NATO',
#  'ORG AC 밀란[SEP]DAT 1989',
#  'PER 박용오[SEP]DAT 1937년 4월 29일',
#  'ORG 중화민국[SEP]LOC 타이베이',
#  'PER 안규백[SEP]ORG 더불어민주당',
#  'PER 하비에르 파스토레[SEP]LOC 아르헨티나',
#  'PER 빌리 아일리시[SEP]POH 싱어송라이터',
#  'ORG 필라델피아 필리스[SEP]PER 박찬호',
#  'ORG 뉴질랜드[SEP]LOC 오클랜드',
#  'PER 미켈란젤로[SEP]DAT 르네상스',
#  'PER 노영민[SEP]ORG 더불어민주당',
#  'PER 이정미[SEP]ORG 정의당',
#  'ORG 제2총군[SEP]ORG 일본 제국 육군',
#  'PER 문성민[SEP]ORG 경기대',
#  'ORG 한국수자원공사[SEP]ORG 환경부',
#  'PER 김종필[SEP]PER 박정희',
#  'PER 스티브 바라캇[SEP]PER Steve Barakatt',
#  'PER 박흥식[SEP]PER 한인하',
#  'ORG 맨체스터 시티 FC[SEP]ORG 프리미어리그',
#  'PER 박병호[SEP]POH 1루수',
#  'PER 노소영[SEP]PER 최태원',
#  'ORG 닛폰햄[SEP]PER 오코소 요시노리',
#  'PER 존 C. 칼훈[SEP]PER 제임스 먼로',
#  'PER 손병희[SEP]ORG 천도교',
#  'ORG 유럽 축구 연맹[SEP]ORG UEFA',
#  'ORG 미국의 소리[SEP]POH Voice of America',
#  'ORG Facebook[SEP]ORG 페이스북',
#  'ORG 두레당[SEP]ORG 유신당',
#  'PER 채리나[SEP]PER 박용근',
#  'PER 마누엘 산치스[SEP]ORG 레알 마드리드',
#  'ORG 흑표당[SEP]PER 휴이 뉴튼',
#  'ORG 곡성군[SEP]PER 유근기',
#  'ORG 경성방직[SEP]PER 김성수',
#  'PER 박애리[SEP]POH 국악인',
#  'ORG HB엔터테인먼트[SEP]PER 문보미',
#  'PER 강경준[SEP]PER 장신영',
#  'PER 스탠 리[SEP]POH 만화가',
#  'ORG 세비야[SEP]LOC 스페인',
#  'ORG 대원방송[SEP]ORG 대원미디어',
#  'ORG 경찰청[SEP]ORG 행정안전부',
#  'PER 제임스 클라크 로스[SEP]DAT 1800년 ~ 1862년',
#  'PER 빌리 파이퍼[SEP]PER 로즈 타일러',
#  'ORG 반민특위[SEP]ORG 특별조사위원회',
#  'PER 드보르작[SEP]POH 작곡가',
#  'ORG 중앙선거관리위원회[SEP]LOC 대한민국',
#  'ORG 몽골 인민 공화국[SEP]POH 공화제',
#  'ORG 자유민주연합[SEP]ORG 한나라당',
#  'PER 김경언[SEP]POH 외야수',
#  'ORG 공무원연금공단[SEP]PER 정남준',
#  'PER 정현왕후[SEP]PER 폐비 윤씨',
#  'ORG 프로이센[SEP]ORG 로마 가톨릭',
#  'PER 카를 5세[SEP]PER 펠리페',
#  'PER 추혜선[SEP]POH 대변인',
#  'PER 차지연[SEP]POH 뮤지컬 배우',
#  'ORG 부산대학교[SEP]PER 전호환',
#  'ORG 곡성군[SEP]PER 유근기',
#  'PER 문재인[SEP]ORG 더불어민주당',
#  'PER 김동성[SEP]DAT 1980년 2월 9일',
#  'PER 이승만[SEP]PER 이인수',
#  'ORG 세리에 B[SEP]ORG 세리에 A',
#  'ORG 목포시[SEP]PER 김종식',
#  'ORG 현대기아차[SEP]ORG 현대모비스',
#  'ORG 롯데 자이언츠[SEP]DAT 1984년',
#  'PER 김기표[SEP]ORG 경성대',
#  'PER 윌리엄 터너[SEP]POH 낭만주의',
#  'ORG 누보톤[SEP]POH 반도체',
#  'PER 디에고 베날리오[SEP]POH 골키퍼',
#  'ORG 독일 연방군[SEP]NOH 49만 5,000명',
#  'ORG 민중당[SEP]ORG 민주당',
#  'PER 이던 앨런[SEP]PER 그린 마운틴 보이스',
#  'ORG 국제축구연맹[SEP]PER 잔니 인판티노',
#  'PER 연갱요[SEP]POH 무원대장군',
#  'PER 문재인[SEP]PER 김정숙',
#  'PER 박마리아[SEP]PER 이기붕',
#  'PER 유곤일[SEP]DAT 청나라',
#  'ORG 방송위원회[SEP]DAT 2008년 2월 29일',
#  'ORG 로센보르그 BK[SEP]DAT 2003',
#  'ORG LG전자[SEP]ORG 금성사',
#  'ORG 진도군[SEP]POH 진도개',
#  'PER 정소동[SEP]POH 영화감독',
#  'ORG 강진군[SEP]LOC 전라남도',
#  'PER 곽지영[SEP]PER 김원중',
#  'PER 미카엘[SEP]DAT 9월 29일',
#  'ORG 광주과학고등학교[SEP]DAT 1984년',
#  'ORG 베트남[SEP]DAT 1954년',
#  'PER 이시영[SEP]PER 이승만',
#  'PER 백한성[SEP]LOC 조선 충청도 공주',
#  'PER 로저 테일러[SEP]POH 드러머',
#  'ORG 광주교육대학교[SEP]PER 최도성',
#  'ORG 북대서양 조약 기구[SEP]ORG NATO',
#  'ORG 익산시[SEP]PER 정헌율',
#  'PER 김대중[SEP]DAT 1987년',
#  'ORG 영광군[SEP]PER 김준성',
#  'PER 성화제[SEP]PER 홍치제',
#  'ORG 울산방송[SEP]ORG ubc',
#  'PER 기요하라 가즈히로[SEP]POH 1루수',
#  'PER 민 리[SEP]POH 캐나다',
#  'ORG 대성여자중학교[SEP]DAT 1959년',
#  'ORG 공무원연금공단[SEP]PER 정남준',
#  'ORG 오번 대학교[SEP]DAT 1856년',
#  'PER 정명화[SEP]POH 첼리스트',
#  'ORG 체트니치[SEP]ORG 유고슬라비아',
#  'ORG 고양시[SEP]NOH 031-909-9000',
#  'ORG AS 로마[SEP]POH 스타디오 올림피코',
#  'PER 김신영[SEP]NOH 48kg',
#  'ORG 성남 FC[SEP]DAT 2014',
#  'PER 박덕흠[SEP]ORG 자유한국당',
#  'PER 심상정[SEP]ORG 정의당',
#  'PER 이진원[SEP]POH 달빛요정',
#  'ORG CJ E&M[SEP]ORG CJ오쇼핑',
#  'PER 이채익[SEP]ORG 자유한국당',
#  'PER 이혜원[SEP]PER 안정환',
#  'PER 김영삼[SEP]DAT 1993년',
#  'PER 마오쩌둥[SEP]ORG 중국 공산당',
#  'PER 심재철[SEP]ORG 자유한국당',
#  'ORG 산업통상자원부[SEP]PER 성윤모',
#  'PER 문무왕[SEP]PER 자의왕후',
#  'ORG 양평군[SEP]PER 정동균',
#  'ORG 툰-운트 스포트버라인 바이어 04 레버쿠젠[SEP]DAT 1904년 7월 1일',
#  'ORG 이니스프리[SEP]ORG 아모레퍼시픽',
#  'PER 소녀시대[SEP]PER 제시카',
#  'PER 스티비 원더[SEP]POH 프로듀서',
#  'ORG 공무원연금공단[SEP]PER 정남준',
#  'ORG 러시아 연방보안국[SEP]ORG 국가보안위원회',
#  'ORG 조선중앙통신사[SEP]LOC 조선민주주의인민공화국',
#  'PER 리사 디 배나[SEP]ORG 오스트레일리아',
#  'ORG 고흥군[SEP]PER 송귀근',
#  'ORG 글래스고[SEP]LOC 스코틀랜드',
#  'ORG 전라남도교육청[SEP]PER 장석웅',
#  'ORG 에든버러 대학교[SEP]LOC 스코틀랜드 에든버러',
#  'ORG 러시아[SEP]LOC 모스크바',
#  'PER 구현모[SEP]ORG KT 커스터머&미디어부문장',
#  'PER 보너 로[SEP]ORG 보수당',
#  'PER 랩몬스터[SEP]PER 방탄소년단',
#  'ORG 자유당[SEP]PER 이승만',
#  'ORG 학성고등학교[SEP]LOC 울산광역시',
#  'ORG 인민수호부대[SEP]ORG 시리아',
#  'ORG 인천 유나이티드 FC[SEP]ORG K리그1',
#  'PER 이개호[SEP]PER 이낙연',
#  'PER 이현성[SEP]POH 미드필더',
#  'ORG 브라질[SEP]ORG 조선민주주의',
#  'PER 다카쿠라 천황[SEP]PER 고시라카와 천황',
#  'ORG 전라북도[SEP]LOC 전주시',
#  'ORG SK 와이번스[SEP]DAT 2018년',
#  'ORG 광신고등학교[SEP]DAT 1987년',
#  'PER 라인홀트 니부어[SEP]ORG 개신교',
#  'ORG KIA 타이거즈[SEP]POH 2009년 한국시리즈',
#  'PER 헌강왕[SEP]DAT 875년',
#  'PER 박주선[SEP]ORG 민생당',
#  'PER 잭 아이언스[SEP]POH 드러머',
#  'PER 김경징[SEP]DAT 1637년 2월 22일',
#  'ORG 메이스트릴리가[SEP]DAT 1992년',
#  'PER 아나킨 스카이워커[SEP]PER 콰이곤 진',
#  'ORG 아프리카TV[SEP]PER 서수길',
#  'ORG 후쿠오카 소프트뱅크 호크스[SEP]DAT 2008',
#  'ORG 뉘른베르크[SEP]ORG 바이에른',
#  'PER 조인철[SEP]POH 광주광역시 문화경제부시장',
#  'PER 강은탁[SEP]PER 신슬기',
#  'ORG 부산과학기술대학교[SEP]PER 강기성',
#  'PER 랩몬스터[SEP]PER 김남준',
#  'ORG 오빠밴드[SEP]ORG MBC',
#  'ORG 서울 해치[SEP]DAT 2011년',
#  'PER 문재인[SEP]LOC 대한민국',
#  'ORG 프리메이라리가[SEP]POH UEFA',
#  'PER 김우빈[SEP]PER 김현중',
#  'ORG 레알 마드리드 카스티야[SEP]POH 세군다 디비시온 B',
#  'PER 후진타오[SEP]PER 장쩌민',
#  'PER 소크라테스[SEP]DAT 기원전 399년',
#  'PER 볼레스와프 3세[SEP]LOC 폴란드',
#  'ORG 통일민주당[SEP]PER 김영삼',
#  'PER 김영삼[SEP]LOC 상도동',
#  'PER 문재인[SEP]ORG 더불어민주당',
#  'ORG 대통합민주신당[SEP]ORG 열린우리당',
#  'ORG 캐나디안 로코모티브 컴퍼니[SEP]LOC 캐나다',
#  'PER 노무현[SEP]LOC 대한민국',
#  'ORG 브리지워터 어소시에이츠[SEP]PER 레이 달리오',
#  'PER 유리 가가린[SEP]POH 비행사',
#  'PER 후지와라[SEP]DAT 아스카 시대',
#  'PER 비틀즈[SEP]PER 폴 매카트니',
#  'ORG 한국타이어앤테크놀로지[SEP]PER 조현범',
#  'PER 한상길[SEP]DAT 1987년 9월 5일',
#  'ORG 11번가[SEP]PER 이상호',
#  'ORG 경남기업[SEP]LOC 대한민국',
#  'PER 필리프 3세[SEP]PER 필리프 4세',
#  'PER 안효섭[SEP]DAT 1995년 4월 17일',
#  'PER 나가시마 시게오[SEP]ORG 요미우리 자이언츠',
#  'PER 쇼니 씨[SEP]PER 少弐氏',
#  'ORG J리그[SEP]NOH 18팀',
#  'ORG 경남대학교[SEP]PER 박재규',
#  'ORG 뉴욕 메츠[SEP]NOH 500만',
#  'ORG 한국서부발전[SEP]PER 김병숙',
#  'ORG 제2군[SEP]POH 제1차 세계 대전',
#  'ORG 해남군[SEP]PER 명현관',
#  'ORG 정읍시[SEP]PER 유진섭',
#  'PER 윌리엄 4세[SEP]PER 빅토리아',
#  'PER 앙리 2세[SEP]PER 프랑수아 1세',
#  'ORG 신천지예수교 증거장막성전[SEP]PER 이만희',
#  'ORG 민주자유당[SEP]ORG 민자당',
#  'PER 백종원[SEP]ORG 더본코리아',
#  'ORG 국제 육상 경기 연맹[SEP]ORG IAAF',
#  'ORG 군사고문단[SEP]NOH 500명',
#  'ORG 고양시[SEP]LOC 경기도',
#  'ORG 전기전자기술자협회[SEP]ORG IEEE',
#  'ORG 한국철도시설공단[SEP]PER 김상균',
#  'PER 방탄소년단[SEP]DAT 2018',
#  'ORG 삼부토건[SEP]ORG 삼부르네상스',
#  'PER 박승원[SEP]DAT 1965년',
#  'PER 칼 12세[SEP]LOC 스웨덴',
#  'ORG 전국교직원노동조합[SEP]ORG 전교조',
#  'PER 태조왕[SEP]DAT 고구려',
#  'PER 박흥식[SEP]DAT 1994년 5월 10일',
#  'PER 김일성[SEP]PER 김성주',
#  'PER 장민철[SEP]DAT 1991년 6월 17일',
#  'PER 버턴 릭터[SEP]POH 물리학',
#  'PER 김대중[SEP]POH 어머니 장수금',
#  'ORG 빈 국립음악예술대학교[SEP]LOC 오스트리아',
#  'PER 야마모토 이소로쿠[SEP]ORG 연합함대 사령장관',
#  'PER 훌라구 칸[SEP]LOC 일 칸국',
#  'ORG 연천군[SEP]PER 김광철',
#  'ORG 민주정의당[SEP]PER 노태우',
#  'ORG 조선의용군[SEP]POH 조선의용대',
#  'PER 김중수[SEP]ORG 한국은행 총재',
#  'PER 아라고른[SEP]LOC 곤도르',
#  'PER 루이 14세[SEP]PER 마리 테레즈',
#  'PER 신문왕[SEP]PER 문무왕',
#  'PER 무함마드[SEP]LOC 메디나',
#  'PER 노태현[SEP]PER JBJ',
#  'ORG BLACKPINK[SEP]ORG 블랙핑크',
#  'PER 유한굉[SEP]LOC 중국 당나라',
#  'ORG KFC[SEP]PER 커널 샌더스',
#  'PER 한용운[SEP]POH 독립운동가',
#  'ORG 민주평화통일자문회의[SEP]POH 대통령',
#  'PER 우에노 주리[SEP]DAT 1986년 5월 25일',
#  'ORG 네이버[SEP]PER 한성숙',
#  'PER 안정환[SEP]PER 이혜원',
#  'PER 이순자[SEP]PER 전두환',
#  'PER 박헌영[SEP]POH 한국 전쟁',
#  'ORG 영암군[SEP]PER 전동평',
#  'ORG 퍼시픽리그[SEP]LOC 일본 프로 야구',
#  'PER 사무드라굽타[SEP]ORG 힌두교',
#  'PER 이민정[SEP]PER 이병헌',
#  'PER 마리 앙트와네트[SEP]PER 루이 16세',
#  'PER 정웅인[SEP]PER 이지인',
#  'ORG 안산 무궁화 축구단[SEP]POH K리그 챌린지',
#  'ORG 아테네[SEP]LOC 그리스',
#  'PER 리처드 닉슨[SEP]ORG 공화당',
#  'PER ROTTA[SEP]DAT 1978년 8월 28일',
#  'PER 이승윤[SEP]POH 개그맨',
#  'ORG 핀란드 능동저항당[SEP]DAT 1904년 11월 17일',
#  'ORG 아프리카 프릭스[SEP]POH 리그 오브 레전드',
#  'ORG 전라북도청[SEP]ORG 행정안전부',
#  'PER 배힘찬[SEP]DAT 1983년 12월 8일',
#  'ORG 삼성전자[SEP]ORG LSI',
#  'PER 제이통[SEP]DAT 1988년 2월 7일',
#  'ORG 경성방직[SEP]PER 김성수',
#  'PER 신의손[SEP]DAT 1960년 1월 12일',
#  'ORG 러시아군[SEP]NOH 25,000',
#  'ORG 조선인민당[SEP]PER 여운형',
#  'ORG 의정부시[SEP]LOC 경기도',
#  'ORG 서울대학교[SEP]DAT 1946년',
#  'ORG 마드리드[SEP]LOC 스페인',
#  'ORG 제주교육대학교[SEP]DAT 2008년 3월 1일',
#  'PER 히로히토[SEP]ORG 일본군',
#  'PER 레오 10세[SEP]PER 조반니 디 로렌초 데 메디치',
#  'PER 김정호[SEP]POH 국회의원',
#  'ORG 텔레노르[SEP]LOC 덴마크',
#  'PER 키드 커디[SEP]DAT 1984년 1월 30일',
#  'PER 칼 12세[SEP]LOC 스웨덴 국왕',
#  'ORG 보건복지부[SEP]PER 박능후',
#  'PER 조동찬[SEP]POH 외야수',
#  'ORG YG엔터테인먼트[SEP]PER 양현석',
#  'PER B.B. 킹[SEP]PER 에릭 클랩튼',
#  'PER 강태환[SEP]POH 색소폰',
#  'PER 하후돈[SEP]PER 하후연',
#  'PER 손병희[SEP]ORG 천도교',
#  'ORG 교황령[SEP]ORG 가톨릭',
#  'ORG 민의원[SEP]PER 곽상훈',
#  'PER 정현백[SEP]PER 문재인',
#  'PER 제임스 6세[SEP]PER 엘리자베스 1세',
#  'PER 조양호[SEP]PER 이명희',
#  'ORG 민주당[SEP]DAT 2016년',
#  'ORG 경상남도[SEP]ORG 창원시',
#  'ORG NC 다이노스[SEP]DAT 2011년',
#  'ORG 법제사법위원회[SEP]PER 여상규',
#  'PER 카르나[SEP]LOC 카우라바',
#  'ORG NC 다이노스[SEP]DAT 2015년',
#  'PER 마크 벌리[SEP]POH 시카고 화이트삭스',
#  'PER 전두환[SEP]PER 이순자',
#  'PER 김익훈[SEP]DAT 1619년',
#  'PER 김태은[SEP]POH 수비수',
#  'PER 배트맨[SEP]POH 다크 나이트',
#  'ORG TWRP 팀[SEP]POH 안드로이드',
#  'PER 자비르 이븐 하이얀[SEP]POH 연금술사',
#  'ORG 하이트진로[SEP]PER 김인규',
#  'PER MC딩동[SEP]PER 허용운',
#  'ORG LG생활건강[SEP]PER 차석용',
#  'PER 김건모[SEP]ORG 건음기획',
#  'ORG 팔레올로고스 왕조[SEP]PER 미하일 8세',
#  'PER 구혜선[SEP]ORG HB엔터테인먼트',
#  'PER 노무현[SEP]LOC 대한민국',
#  'ORG 삼성 라이온즈[SEP]DAT 2014년',
#  'PER 자크 카르티에[SEP]LOC 프랑스',
#  'ORG 더불어민주당[SEP]DAT 2016년',
#  'PER 설공검[SEP]DAT 1302년',
#  'ORG 신안군[SEP]PER 박우량',
#  'ORG 민주정의당[SEP]PER 전두환',
#  'PER 카게야마 슌[SEP]POH 가면라이더',
#  'PER 김정숙[SEP]PER 문재인',
#  'PER 연정훈[SEP]PER 한가인',
#  'ORG 한국동서발전[SEP]PER 박일준',
#  'PER 이이 나오스케[SEP]ORG 히코네 번',
#  'ORG 새천년민주당[SEP]ORG 열린우리당',
#  'ORG 아시아나항공[SEP]ORG HDC현대산업개발',
#  'ORG 수원 삼성 블루윙즈[SEP]DAT 2004',
#  'PER 박헌영[SEP]ORG 조선로동당',
#  'ORG 보루시아 도르트문트[SEP]ORG 분데스리가',
#  'PER 베네딕토 16세[SEP]PER 요한 바오로 2세',
#  'ORG CBS[SEP]LOC 대한민국',
#  'PER 도쿠가와 이에미쓰[SEP]ORG 에도 막부',
#  'ORG 독립국가연합[SEP]ORG CIS',
#  'ORG 토론토 블루제이스[SEP]DAT 1993',
#  'ORG 현대차 그룹[SEP]ORG 현대모비스',
#  'PER 육영수[SEP]DAT 1974년 8월 15일',
#  'ORG AFC 아약스[SEP]DAT 2012-13',
#  'PER 김예림[SEP]DAT 투개월',
#  'ORG 상주 상무[SEP]DAT 2013',
#  'ORG 더불어민주당[SEP]PER 문재인',
#  'PER 킴 리틀[SEP]ORG 아스널',
#  'PER 블라디미르 게레로 주니어[SEP]DAT 1999년 3월 16일',
#  'PER 이종욱[SEP]DAT 2008년',
#  'PER 장경진[SEP]ORG 전남 드래곤즈',
#  'ORG GO 트랜싯[SEP]LOC 캐나다',
#  'ORG 서울형사지방법원[SEP]ORG 서울지방법원',
#  'ORG KIA 타이거즈[SEP]DAT 2011년',
#  'ORG 더불어민주당[SEP]DAT 2016년',
#  'PER 비카르나[SEP]LOC 판다바',
#  'ORG 동아일보[SEP]DAT 1920년',
#  'ORG 소련군[SEP]NOH 37,000명',
#  'ORG 유벤투스[SEP]LOC 토리노',
#  'PER 젝스키스[SEP]PER 은지원',
#  'PER 권창훈[SEP]ORG 프라이부르크',
#  'ORG 전라남도교육청[SEP]PER 장석웅',
#  'ORG 뉴사우스웨일스[SEP]ORG 시드니',
#  'ORG 더불어민주당[SEP]PER 문재인',
#  'PER 주시은[SEP]POH 아나운서',
#  'ORG 경남대학교[SEP]PER 박재규',
#  'ORG 롯데 자이언츠[SEP]DAT 1984년',
#  'PER 나훈아[SEP]POH 트로트',
#  'PER 광해군[SEP]PER 폐세자 이질',
#  'ORG CJ그룹[SEP]PER 이재현',
#  'ORG 몽골 인민 공화국[SEP]POH 공산주의',
#  'ORG 하나금융그룹[SEP]PER 김정태',
#  'ORG 컴캐스트[SEP]ORG NBC 유니버설',
#  'PER 리셴녠[SEP]DAT 1909년 6월 23일',
#  'PER 조영래[SEP]POH 변호사',
#  'ORG 양평군[SEP]LOC 경기도',
#  'PER 차인하[SEP]PER 이재호',
#  'PER 최한림[SEP]DAT 1971년 11월 15일',
#  'ORG 광양시[SEP]NOH 10개',
#  'ORG 캐나다[SEP]LOC 토론토',
#  'PER 박진영[SEP]POH 안무가',
#  'PER 서기석[SEP]DAT 1953년 2월 19일',
#  'PER 마동석[SEP]PER 이동석',
#  'ORG 대한민국 임시정부[SEP]LOC 상하이',
#  'PER 신채호[SEP]POH 역사학자',
#  'PER 미카엘 7세[SEP]PER 로마누스 4세',
#  'PER 정호용[SEP]PER 노신영',
#  'ORG 호텔 델루나[SEP]PER 여진구',
#  'PER 에드워드 7세[SEP]PER 루이즈',
#  'PER 다마키 고지[SEP]PER 玉置浩二',
#  'PER 유재석[SEP]PER 유느님',
#  'PER 공원왕후[SEP]PER 충숙왕',
#  'PER 닥터 에그맨[SEP]PER 아이보 로보트닉',
#  'ORG 고양시[SEP]ORG 경기도',
#  'PER 카도야 츠카사[SEP]ORG 디케이드',
#  'ORG 담양군[SEP]PER 최형식',
#  'PER 안철수[SEP]DAT 1962년 2월 26일',
#  'ORG 제102보충대대[SEP]ORG 제1야전군',
#  'PER 구승리[SEP]ORG 썬더스톰 야구단',
#  'PER 황바울[SEP]PER 간미연',
#  'ORG 광주광역시[SEP]PER 이용섭',
#  'PER 장쉐량[SEP]ORG 동북군',
#  'ORG 보건복지부[SEP]PER 박능후',
#  'PER 하태경[SEP]ORG 국방위원회',
#  'ORG 민주당[SEP]DAT 2016년',
#  'ORG 퍼시픽 리그[SEP]POH 일본 프로 야구',
#  'PER 이범호[SEP]ORG 한화 이글스',
#  'PER 린킨 파크[SEP]PER 체스터 베닝턴',
#  'PER 유은혜[SEP]POH 사회부총리 겸 교육부장관',
#  'PER 정복동[SEP]PER 김병철',
#  'ORG 세레소 오사카[SEP]DAT 2018',
#  'PER 다리우스 1세[SEP]PER 크세르크세스 1세',
#  'ORG 해남군[SEP]PER 명현관',
#  'ORG 개혁결집회[SEP]ORG 민진당',
#  'PER 람캄행[SEP]POH 쓰엉 부인',
#  'ORG 메르세데스 벤츠[SEP]POH 자동차',
#  'PER 서필상[SEP]LOC 산청함양거창합천',
#  'ORG 전주 매그 FC[SEP]LOC 전라북도 전주시',
#  'ORG 세리에 B[SEP]ORG 세리에 C',
#  'PER 송제헌[SEP]POH 공격수',
#  'ORG 화순군[SEP]PER 구충곤',
#  'PER 김재걸[SEP]ORG 삼성 라이온즈',
#  'PER 숙의 박씨[SEP]PER 영온옹주',
#  'ORG 장덕도서관[SEP]LOC 광산구',
#  'ORG FC 포르투[SEP]DAT 2010',
#  'PER 알프레드 노벨[SEP]LOC 스웨덴',
#  'ORG 평화민주당[SEP]PER 김대중',
#  'PER 디코이[SEP]ORG 롤링컬쳐원',
#  'PER 에릭 울프슨[SEP]ORG 알란 파슨스 프로젝트',
#  'ORG 김천교육지원청[SEP]ORG 경상북도교육청',
#  'PER 임은수[SEP]DAT 2003년 2월 26일',
#  'ORG 대안신당[SEP]PER 최경환',
#  'ORG 곡성군[SEP]PER 유근기',
#  'ORG KBS 전주방송총국[SEP]ORG KBS 全州放送總局',
#  'PER 유지태[SEP]PER 김효진',
#  'ORG 분데스리가[SEP]POH DFB-포칼',
#  'PER 이혜리[SEP]PER 걸스데이',
#  'PER 존 C. 브레킨리지[SEP]ORG 민주당',
#  'PER 루이 15세[SEP]PER 빅투아르',
#  'PER 조코위[SEP]ORG 민주항쟁당',
#  'ORG 평화민주당[SEP]PER 김대중',
#  'PER 조봉암[SEP]ORG 진보당',
#  'PER 정길화[SEP]POH 연출가',
#  'ORG 모스크바[SEP]LOC 러시아',
#  'PER 쇼 야노[SEP]DAT 1990년 10월 22일',
#  'ORG 바이어 04 레버쿠젠[SEP]ORG 분데스리가',
#  'ORG 나주시[SEP]LOC 전라남도',
#  'PER 안토니오 비발디[SEP]POH 바이올린',
#  'PER 고촉통[SEP]LOC 싱가포르',
#  'PER 김대중[SEP]DAT 1987년',
#  'ORG 민주평화통일자문회의[SEP]PER 정세현',
#  'PER 손흥민[SEP]ORG 토트넘 홋스퍼',
#  'ORG 폴란드[SEP]DAT 1989년',
#  'ORG 한국자산관리공사[SEP]PER 문성유',
#  'PER 함연지[SEP]POH 뮤지컬 배우',
#  'ORG 스페인[SEP]NOH 6,000명',
#  'ORG 코파 델 레이[SEP]POH 스페인',
#  'ORG 폴란드 인민 공화국[SEP]POH 공산주의',
#  'ORG SK하이닉스[SEP]ORG SK텔레콤',
#  'PER 로버트 팰컨 스콧[SEP]POH 군인, 탐험가',
#  'PER 김복동[SEP]POH 인권운동가',
#  'PER 정용진[SEP]ORG 신세계그룹',
#  'ORG 기획재정부[SEP]ORG 기재부',
#  'PER 구시 칸[SEP]DAT 1582년',
#  'PER 양녕대군[SEP]DAT 1394년',
#  'ORG 일본군[SEP]ORG 일본 제국',
#  'PER 요제프 1세[SEP]DAT 1711년 4월 17일',
#  'ORG 아시아축구연맹[SEP]ORG AFC',
#  'ORG 롤링 스톤스[SEP]POH Aftermath',
#  'ORG 아틀레티코 마드리드[SEP]ORG 프리메라리가',
#  'ORG 국제올림픽위원회[SEP]ORG IOC',
#  'PER 김혁종[SEP]ORG 광주대학교',
#  'PER 류경수[SEP]DAT 1915년 9월 9일 ~ 1958년 11월 19일',
#  'ORG 전주지방검찰청[SEP]ORG 광주고등검찰청',
#  'ORG 국민볼셰비키당[SEP]PER 에두아르드 리모노프',
#  'PER 이태승[SEP]POH TEEN TEEN',
#  'ORG 공무원연금공단[SEP]PER 정남준',
#  'ORG 인테르나치오날레[SEP]POH UEFA',
#  'PER 바그다드 부네자[SEP]PER Baghdad Bounedjah',
#  'ORG 내셔널리그[SEP]POH K리그',
#  'PER 개로왕[SEP]PER 문주왕',
#  'ORG 아시아나항공[SEP]ORG 스타얼라이언스',
#  'ORG 인강여객[SEP]LOC 인천광역시',
#  'PER 이봉의[SEP]PER 이기원',
#  'ORG 삼성전자[SEP]ORG LSI',
#  'PER 무함마드 아민 칸[SEP]DAT 1855년',
#  'PER 러블리즈[SEP]ORG Lovelyz',
#  'ORG 민주통합당[SEP]ORG 더불어민주당',
#  'PER 임동혁[SEP]DAT 1984년 7월 25일',
#  'PER 페넬로페 크루스 산체스[SEP]DAT 1974년 4월 28일',
#  'ORG 조선총독부[SEP]DAT 1910년 10월 1일',
#  'PER 이스마일 2세[SEP]PER 타흐마스프 1세',
#  'ORG 유진기업[SEP]ORG 유진투자증권',
#  'ORG 아메리카 혁명인민동맹[SEP]DAT 1924년 5월 7일',
#  'ORG 브리티시컬럼비아 대학교[SEP]LOC 캐나다',
#  'PER 바즈겐 사르키샨[SEP]DAT 1959년 3월 5일',
#  'PER 이용섭[SEP]ORG 더불어민주당',
#  'PER 루이스 해밀턴[SEP]ORG 맥라렌',
#  'ORG 신안군[SEP]PER 박우량',
#  'ORG 동명대[SEP]PER 정홍섭',
#  'PER 애들레이 스티븐슨[SEP]ORG 민주당',
#  'PER 김수자[SEP]DAT 1957년',
#  'PER 박근혜[SEP]ORG 자유한국당',
#  'PER 루시드 폴[SEP]PER 미선이',
#  'ORG 유네스코[SEP]POH 인류무형문화유산',
#  'ORG YG엔터테인먼트[SEP]PER 양현석',
#  'ORG 키움증권[SEP]ORG 다우기술',
#  'PER 겔러트 그린델왈드[SEP]PER 알버스 덤블도어',
#  'ORG 조선인민군[SEP]ORG 조선민주주의인민공화국',
#  'ORG 씨제이엔터테인먼트[SEP]ORG 씨제이이에치(주)',
#  'ORG 랄라블라[SEP]ORG GS리테일',
#  'ORG 우리당[SEP]PER 노무현',
#  'PER 하드리아누스[SEP]LOC 로마 제국',
#  'PER 네부카드네자르 2세[SEP]LOC 신바빌로니아',
#  'PER 이은권[SEP]ORG 자유한국당',
#  'PER 의경세자[SEP]PER 정희왕후',
#  'PER 데이비드 흄[SEP]DAT 1776년 8월 25일',
#  'ORG 조국전선[SEP]PER 엥겔베르트 돌푸스',
#  'PER 김성주[SEP]LOC 대한민국',
#  'ORG 대한축구협회[SEP]ORG KFA',
#  'ORG 전북 현대 모터스[SEP]DAT 2000',
#  'PER 정동영[SEP]ORG 국민의당',
#  'ORG 경남대학교[SEP]PER 박재규',
#  'PER 심진화[SEP]PER 김원효',
#  'PER 재커리 테일러[SEP]ORG 휘그당',
#  'ORG 세르비아[SEP]POH 베오그라드',
#  'ORG DELAG[SEP]DAT 1909년 11월 16일',
#  'ORG 중소벤처기업진흥공단[SEP]ORG 중진공',
#  'PER 심재철[SEP]POH 국회부의장',
#  'PER 최수종[SEP]PER 하희라',
#  'ORG 분데스리가[SEP]DAT 1963년',
#  'ORG 노바야 가제타[SEP]POH 자유주의',
#  'PER 세르반테스[SEP]LOC 스페인',
#  'PER 도조 히데키[SEP]ORG 일본 제국',
#  'ORG 제15특수임무비행단[SEP]ORG 대한민국 공군',
#  'PER 지네딘 지단[SEP]ORG 레알 마드리드',
#  'ORG 세리에 A[SEP]ORG AC 밀란',
#  'PER 이유현[SEP]POH 수비수',
#  'ORG 투니버스[SEP]POH 애니메이션',
#  'PER 마리오 켐페스[SEP]POH 축구선수',
#  'PER 샬롯 스무디[SEP]ORG 빅 맘 해적단',
#  'ORG 해적당[SEP]ORG 스웨덴',
#  'PER 백선엽[SEP]PER 박정희',
#  'ORG 일본 기상청[SEP]ORG JMA',
#  'PER 송시열[SEP]PER 송갑조',
#  'ORG 동양방송[SEP]ORG TBC',
#  'ORG 러시아[SEP]ORG 모스크바',
#  'ORG 건강보험심사평가원[SEP]ORG 보건복지부',
#  'PER 카데르 칸[SEP]POH 캐나다',
#  'PER 펑더화이[SEP]PER 린뱌오',
#  'ORG FC 서울[SEP]DAT 1985',
#  'PER 마오쩌둥[SEP]DAT 청나라',
#  'ORG 인테르나치오날레[SEP]POH 세리에 A',
#  'PER 페데리코 프랑코[SEP]ORG 자유당',
#  'PER 베스파시아누스[SEP]PER 티투스',
#  'ORG 호조씨[SEP]ORG 後北条氏',
#  'PER 류현진[SEP]NOH 8000만달러',
#  'ORG 러시아 차르국[SEP]ORG 모스크바 차르국',
#  'ORG 전북현대[SEP]POH K리그1',
#  'ORG 크로아티아[SEP]DAT 1998년 FIFA 월드컵',
#  'ORG 전국민주노동조합총연맹[SEP]PER 한상균',
#  'PER 김대중[SEP]PER 김홍업',
#  'PER 안토니우 구테흐스[SEP]LOC 포르투갈',
#  'PER 헨리 7세[SEP]PER 리처드 3세',
#  'PER 루이스 해밀턴[SEP]ORG 맥라렌',
#  'ORG 한나라당[SEP]DAT 2012년 2월 13일',
#  'PER 스텔리오스 얀나코풀로스[SEP]ORG 그리스',
#  'PER 케이틀린 오스먼드[SEP]LOC 캐나다',
#  'PER 박병호[SEP]POH 1루수',
#  'ORG 뉴욕 양키스[SEP]DAT 1995',
#  'ORG 나랏말싸미[SEP]PER 송강호',
#  'PER 프랭크 로이드 라이트[SEP]POH 건축가',
#  'PER 권선화[SEP]PER 김윤진',
#  'PER 아우구스투스[SEP]PER 티베리우스',
#  'ORG 미국 에너지부[SEP]DAT 1977년 8월 4일',
#  'ORG 한국남동발전[SEP]PER 유향열',
#  'PER 하드리아누스[SEP]ORG 로마 제국',
#  'ORG 함부르크 SV[SEP]DAT 2008',
#  'ORG 인테르나치오날레[SEP]ORG 밀라노',
#  'ORG 영암군[SEP]PER 전동평',
#  'ORG 한국환경산업기술원[SEP]PER 남광희',
#  'PER 오페스[SEP]LOC 스웨덴',
#  'ORG 코리아세븐[SEP]ORG 세븐일레븐',
#  'PER 판 니스텔로이[SEP]ORG 네덜란드',
#  'PER 허버트 후버[SEP]ORG 공화당',
#  'ORG 유럽 축구 연맹[SEP]POH UEFA',
#  'PER 베르트 판 마르바이크[SEP]ORG 네덜란드',
#  'ORG 국립중앙도서관[SEP]ORG 국립장애인도서관',
#  'ORG 방위사업청[SEP]ORG 국방부',
#  'PER 니콜라이 림스키코르사코프[SEP]POH 작곡가',
#  'ORG 흥선군[SEP]PER 이하응',
#  'PER 안네 매키넨[SEP]ORG 워싱턴 프리덤',
#  'ORG FC 도쿄[SEP]DAT 2009',
#  'PER 마거릿 대처[SEP]ORG 보수당',
#  'PER 피르미누[SEP]ORG 브라질',
#  'PER 근녕군[SEP]PER 정빈 고씨',
#  'ORG 유럽 축구 연맹[SEP]ORG UEFA',
#  'PER 마리 앙투아네트[SEP]PER 루이 16세',
#  'PER 미야모토 신야[SEP]POH 유격수',
#  'ORG 국민의당[SEP]PER 안철수',
#  'PER 토니 블레어[SEP]ORG 노동당',
#  'PER 유향열[SEP]POH 한국남동발전 사장',
#  'ORG 고흥군[SEP]PER 송귀근',
#  'ORG 칼마르 동맹[SEP]LOC 덴마크',
#  'PER 정경두[SEP]ORG 국방부 장관',
#  'PER 구카이[SEP]ORG 진언종',
#  'PER 쟝쩐위[SEP]ORG 중앙희극학원',
#  'ORG 한국e스포츠협회[SEP]POH KeSPA',
#  'ORG 우크라이나 프리미어리그[SEP]ORG FC 디나모 키예프',
#  'ORG 제일약품[SEP]ORG 주식회사',
#  'PER 조병옥[SEP]POH 내무부 장관',
#  'PER 팽옥린[SEP]POH 수사제독',
#  'PER 알렉산더 4세[SEP]DAT 기원전 323년',
#  'ORG 안산시[SEP]LOC 경기도',
#  'ORG 여수시[SEP]PER 권오봉',
#  'PER 진선미[SEP]POH 변호사',
#  'PER 최영도[SEP]PER 김우빈',
#  'PER 연남생[SEP]PER 연헌성',
#  'PER 드미트리 메드베데프[SEP]PER 블라디미르 푸틴',
#  'ORG PSV 에인트호번[SEP]ORG 네덜란드',
#  'ORG 해남군[SEP]PER 명현관',
#  'ORG FC 크로토네[SEP]DAT 1910년',
#  'PER 강은비[SEP]PER 주미진',
#  'ORG 리가 I[SEP]ORG 루마니아',
#  'PER 이시언[SEP]LOC 상도동',
#  'ORG 부산대학교[SEP]PER 전호환',
#  'ORG 뉴욕 시티 FC[SEP]DAT 2015년',
#  'ORG 민주당[SEP]ORG 민중당',
#  'ORG 세비야[SEP]LOC 스페인',
#  'ORG 경남대학교[SEP]PER 박재규',
#  'PER 아르투로 토스카니니[SEP]POH 지휘자',
#  'ORG 오뚜기[SEP]PER 함태호',
#  'ORG 인사혁신처[SEP]ORG 인사처',
#  'PER 김아랑[SEP]POH 쇼트트랙',
#  'ORG 농림축산식품부[SEP]ORG 농식품부',
#  'ORG 한국철도공사[SEP]POH 전라선',
#  'PER 에리얼[SEP]POH 인어공주',
#  'ORG 뉴욕 양키스[SEP]DAT 1928',
#  'PER 김복진[SEP]DAT 1901년',
#  'PER 조지 5세[SEP]PER 에드워드 8세',
#  'PER 키리아코스 파파도풀로스[SEP]DAT 1992년 2월 23일',
#  'PER 넋업샨[SEP]DAT 1979년 9월 20일',
#  'ORG 지상작전사령부[SEP]ORG 제1, 3야전군',
#  'ORG 조선인민공화국[SEP]PER 여운형',
#  'PER 바오다이[SEP]PER 응우옌',
#  "PER 최성은[SEP]POH 시동'",
#  'ORG FC 인테르나치오날레 밀라노[SEP]POH 세리에 A',
#  'ORG 스타일쉐어[SEP]PER 윤자영',
#  'PER 박정희[SEP]DAT 1979년 10월 26일',
#  'PER 지승민[SEP]DAT 1978년 9월 12일',
#  'ORG 광주여자대학교[SEP]NOH 69명',
#  'ORG 보건복지부[SEP]PER 박능후',
#  'PER 콘라트 2세[SEP]PER 기젤라',
#  'ORG 인테르나치오날레[SEP]ORG 밀라노',
#  'PER 욤비 토나[SEP]DAT 2002년',
#  'ORG 영광군[SEP]PER 김준성',
#  'ORG 화순군[SEP]PER 구충곤',
#  'PER 피치치[SEP]PER 디에고 포를란',
#  'PER 박재규[SEP]ORG 경남대학교',
#  'ORG 싸이월드[SEP]DAT 1999년 9월',
#  'PER 구혜선[SEP]PER 안재현',
#  'ORG 한국프로야구[SEP]ORG KBO',
#  'PER 어기구[SEP]ORG 더불어민주당',
#  'PER 피에트로 바돌리오[SEP]ORG 이탈리아',
#  'PER 티모 힐데브란트[SEP]PER Timo Hildebrand',
#  'PER 수비 권씨[SEP]PER 충숙왕',
#  'ORG S★스파이시[SEP]ORG 스타더스트 프로모션',
#  'ORG 상하이 선화[SEP]ORG 베이징 궈안',
#  'PER 김이지[SEP]PER 김희정',
#  'ORG 수원 삼성 블루윙즈[SEP]DAT 2008',
#  'PER 베네딕토 16세[SEP]DAT 1927년 4월 16일',
#  'PER MFBTY[SEP]PER 윤미래',
#  'PER 이어령[SEP]POH 문학평론가',
#  'ORG 홍문관[SEP]ORG 예문관',
#  'PER 기시 노부스케[SEP]LOC 상공성',
#  'ORG 아스타나[SEP]LOC 카자흐스탄',
#  'PER 슈테판 츠바이크[SEP]LOC 오스트리아',
#  'PER 딥플로우[SEP]PER Deepflow',
#  'PER 안소미[SEP]NOH KBS 24기 공채 개그맨',
#  'ORG 서울 이랜드 FC[SEP]POH K리그 챌린지',
#  'PER 개로왕[SEP]PER 문주왕',
#  'ORG 니켈로디언 무비스[SEP]POH 애니메이션',
#  'PER 서재필[SEP]POH 독립운동가',
#  'ORG 더불어민주당[SEP]PER 문재인',
#  'ORG 롯데 자이언츠[SEP]ORG 개성고등학교',
#  'PER 사비니아노[SEP]DAT 604년 9월 13일',
#  'PER 이와사키 타카후미[SEP]POH 기타리스트',
#  'ORG 네덜란드[SEP]DAT 1715년',
#  'ORG 국립수목원[SEP]PER 이유미',
#  'ORG 이수건설[SEP]ORG 브라운스톤',
#  'ORG 식품의약품안전처[SEP]ORG 식약처',
#  'PER 고연무[SEP]DAT 고구려',
#  'PER 이강인[SEP]LOC 발렌시아',
#  'PER 야로슬라블[SEP]ORG 러시아',
#  'ORG 마이크로 센터[SEP]PER 빌 베인',
#  'PER 안상수[SEP]PER 송영길',
#  'PER 헤디 라마르[SEP]LOC 오스트리아',
#  'PER 전태일[SEP]ORG 개신교',
#  'PER 진덕여왕[SEP]PER 선덕여왕',
#  'PER 최규성[SEP]DAT 1950년 2월 4일',
#  'ORG 중앙도서관[SEP]ORG 시흥시',
#  'PER 엔리코 단돌로[SEP]LOC 베네치아 공화국',
#  'ORG 코모로[SEP]ORG 프랑스어',
#  'ORG 울산항만공사[SEP]PER 고상환',
#  'ORG 피츠버그 파이리츠[SEP]DAT 1979',
#  'PER 위키미키[SEP]ORG 판타지오',
#  'ORG 유럽 축구 연맹[SEP]ORG UEFA',
#  'PER 고이케 유리코[SEP]LOC 도쿄도지사',
#  'PER 권양숙[SEP]PER 노무현',
#  'ORG 서울대학교[SEP]DAT 1946년',
#  'ORG 고흥군[SEP]PER 송귀근',
#  'PER 전희경[SEP]POH 비례대표',
#  'PER 빌 클린턴[SEP]ORG 민주당',
#  'ORG 전라남도교육청[SEP]PER 장석웅',
#  'ORG 배고픈공룡[SEP]ORG 생각투자',
#  'ORG 내무인민위원회[SEP]ORG 국가정치부',
#  'ORG 크라이엔진[SEP]POH 게임 엔진',
#  'ORG 리드 칼리지[SEP]LOC 오리건주 포틀랜드',
#  'PER 마이클 잭슨[SEP]POH Thriller',
#  'PER 이기붕[SEP]ORG 자유당',
#  'ORG 평화민주당[SEP]PER 김대중',
#  'PER 낙선군[SEP]DAT 1641년 음력 11월 7일',
#  'PER 멜리나 메르쿠리[SEP]LOC 그리스',
#  'PER 김한신[SEP]ORG 화순옹주',
#  'ORG 현대 유니콘스[SEP]DAT 1998년',
#  'PER 루이 2세 당주[SEP]PER 욜란다 데 아라곤',
#  'ORG SK텔레콤[SEP]PER 박정호',
#  'ORG 중국 공산당[SEP]ORG 인민일보',
#  'PER 킵루츠[SEP]PER Keeproots',
#  'ORG 스위스[SEP]NOH 18,000명',
#  'ORG 레크레아티보[SEP]POH 세군다 디비시온',
#  'PER 람베르토 2세[SEP]DAT 898년 10월 15일',
#  'ORG 두산 베어스[SEP]DAT 1986년',
#  'ORG 통일민주당[SEP]PER 김영삼',
#  'ORG 애틀랜타 브레이브스[SEP]DAT 1995',
#  'PER 배삼룡[SEP]POH 코미디언',
#  'ORG 종로도서관[SEP]ORG 경성도서관',
#  'ORG 경주시[SEP]ORG 경상북도',
#  'PER 스티브 러셀[SEP]POH 스페이스워!',
#  'ORG FC 지롱댕 드 보르도[SEP]DAT 2008-09',
#  'ORG 오뚜기[SEP]PER 이강훈',
#  'PER 박녹주[SEP]POH 판소리',
#  'ORG 한화 이글스[SEP]DAT 1999년',
#  'ORG 베트남 정부[SEP]LOC 하노이',
#  'ORG 공무원연금공단[SEP]PER 정남준',
#  'PER 나경은[SEP]PER 유재석',
#  'ORG 경성대학교[SEP]PER 송수건',
#  'PER 송하예[SEP]ORG 더하기미디어',
#  'PER 가타오카 시치로[SEP]ORG 일본 제국 해군',
#  'PER 김대중[SEP]PER 이희호',
#  'PER 도쿠가와 이에야스[SEP]ORG 에도 막부',
#  'ORG 반민특위[SEP]ORG 반민족행위특별조사위원회',
#  'ORG 한국철도공사[SEP]POH 경원선',
#  'ORG 정의당[SEP]ORG 노동당',
#  'ORG 새로운보수당[SEP]ORG 미래통합당',
#  'ORG 공화국연합[SEP]PER 자크 시라크',
#  'ORG 고베 시[SEP]LOC 효고현',
#  'ORG 시드니[SEP]LOC 오스트레일리아',
#  'PER 아냐 미타크[SEP]ORG VfB 포르투나 켐니츠',
#  'ORG 제주도[SEP]ORG 제주특별자치도',
#  'ORG 문민정부[SEP]POH 국민의 정부',
#  'ORG 노동당[SEP]ORG 진보신당',
#  'ORG 공화인민당[SEP]ORG CHP',
#  'PER 소나타 아티카[SEP]LOC 핀란드',
#  'PER 김미화[SEP]DAT 1964년 9월 22일',
#  'PER 백승호[SEP]ORG 수원 삼성 블루윙즈 U-15',
#  'PER 황교안[SEP]PER 박근혜',
#  'ORG 한국동서발전[SEP]PER 박일준',
#  'ORG 삼성 라이온즈[SEP]DAT 1999년',
#  'ORG 경산교육지원청[SEP]ORG 경상북도교육청',
#  'ORG 이스라엘클럽[SEP]ORG 하포엘 텔아비브',
#  'PER 프랭크 자파[SEP]DAT 1940년 12월 21일',
#  'ORG 민주당[SEP]PER 김대중',
#  'ORG 한국동서발전[SEP]PER 박일준',
#  'PER 송광민[SEP]ORG 한화 이글스',
#  'PER 제임스 먼로[SEP]PER James Monroe',
#  'ORG 광주광역시[SEP]PER 이용섭',
#  'PER 일라누[SEP]ORG 브라질',
#  'PER 아베 신조[SEP]PER 아베 아키에',
#  'ORG 우리당[SEP]PER 노무현',
#  'ORG 한국GM[SEP]ORG 자동차',
#  'PER 루자인 알하틀룰[SEP]LOC 사우디아라비아',
#  'PER 김종호[SEP]LOC 대한민국',
#  'PER 전두환[SEP]PER 전재용',
#  'PER 최인호[SEP]ORG 부산시당 위원장',
#  'ORG 고려대학교 안산병원[SEP]DAT 1985년',
#  'PER 짐 켈러[SEP]POH 엔지니어',
#  'ORG 통합진보당[SEP]DAT 2011년 12월 13일',
#  'PER 기성용[SEP]PER 한혜진',
#  'PER 코치시 졸탄[SEP]LOC 헝가리',
#  'PER 바디 알자만[SEP]DAT 1517년',
#  'PER 김부겸[SEP]PER 문재인',
#  'PER 홍난파[SEP]PER 홍영후',
#  'PER 아우구스투스[SEP]PER 율리우스 카이사르',
#  'PER 변희재[SEP]POH 미디어워치',
#  'ORG SS-FHA[SEP]ORG 친위대 지도본부',
#  'PER 류현진[SEP]ORG 한화 이글스',
#  'PER 고용희[SEP]PER 김정일',
#  'ORG 해태 타이거즈[SEP]DAT 1996',
#  'PER 신숙주[SEP]PER 고령군',
#  'PER 샤를 8세[SEP]PER 루이 11세',
#  'ORG 보카 주니어스[SEP]LOC 아르헨티나',
#  'ORG 갈리마르[SEP]POH 프랑스',
#  'PER 시황제[SEP]DAT 진나라',
#  'ORG 삼성전자[SEP]ORG AKG',
#  'ORG 보루시아 도르트문트[SEP]DAT 2017',
#  'PER 김창익[SEP]ORG 산울림',
#  'ORG 화순군[SEP]PER 구충곤',
#  'PER 가미오 요코[SEP]POH 꽃보다 남자',
#  'ORG 첼시 FC[SEP]ORG 프리미어 리그',
#  'ORG 한국선급[SEP]PER 이정기',
#  'ORG 제95민사여단[SEP]ORG 미국 육군',
#  'PER 정종제[SEP]LOC 광주광역시 행정부시장',
#  'PER 손경식[SEP]ORG CJ그룹 회장',
#  'ORG LG화학[SEP]ORG LG그룹',
#  'ORG 바르셀로나[SEP]LOC 스페인',
#  'ORG 경남대[SEP]PER 박재규',
#  'PER 옌시산[SEP]DAT 1930년',
#  'ORG 블루핸즈[SEP]ORG 현대자동차',
#  'ORG 고흥군[SEP]PER 송귀근',
#  'ORG 엠브라에르[SEP]ORG 브라질',
#  'ORG 러시아[SEP]LOC 모스크바',
#  'ORG 광양읍[SEP]ORG 광양시',
#  'PER 음갈문왕[SEP]PER 선덕여왕',
#  'PER 마츠다 유사쿠[SEP]DAT 1949년 9월 21일',
#  'PER 오르토나[SEP]LOC 이탈리아',
#  'PER 윤소하[SEP]ORG 정의당',
#  'PER 아르주나[SEP]PER 크리슈나',
#  'PER 마르그레테 1세[SEP]PER 발데마르 4세',
#  'PER 강지환[SEP]PER 조태규',
#  'PER 버러스 프레더릭 스키너[SEP]DAT 1990년 8월 18일',
#  'ORG 단대신문[SEP]ORG 단국대학교',
#  'ORG 문민정부[SEP]PER 김영삼',
#  'ORG 부천 FC 1995[SEP]PER 송선호',
#  'PER 노무현[SEP]LOC 대한민국',
#  'PER 류호정[SEP]ORG 정의당',
#  'ORG 광주여자대학교[SEP]PER 이선재',
#  'ORG 전남여상[SEP]PER 최규명',
#  'PER 후지코 F. 후지오[SEP]PER 도라에몽',
#  'ORG 인천광역시[SEP]PER 도성훈',
#  'PER 박항서[SEP]PER 거스 히딩크',
#  'ORG 린나이코리아[SEP]PER 강영철',
#  'PER 리콴유[SEP]LOC 싱가포르',
#  'PER 조석준[SEP]LOC 대한민국 공군 대위',
#  'PER 아레니우스[SEP]LOC 스웨덴',
#  'ORG 안산 무궁화 축구단[SEP]DAT 2016년',
#  'ORG 에어 트랜샛[SEP]LOC 캐나다 퀘벡주 몬트리올',
#  'ORG 레알 마드리드[SEP]LOC 발데베바스',
#  'ORG 포천시[SEP]PER 박윤국',
#  'PER 체 게바라[SEP]LOC 볼리비아',
#  'ORG 목포시[SEP]PER 김종식',
#  'ORG 광주 상무 축구단[SEP]ORG K리그',
#  'PER 김경기[SEP]POH 1루수',
#  'PER 박정희[SEP]ORG 민주공화당',
#  'ORG 신한국당[SEP]PER 이회창',
#  'ORG 월트 디즈니[SEP]POH 애니메이터',
#  'PER 루디 푈러[SEP]ORG 독일 대표팀',
#  'ORG FIFPro[SEP]ORG 국제축구선수협회',
#  'PER 숙의 이씨[SEP]LOC 양평군',
#  'PER 나희선[SEP]ORG 샌드박스 네트워크',
#  'PER 정석규[SEP]ORG 신양문화재단',
#  'ORG 원나라[SEP]DAT 명나라',
#  'PER 임종식[SEP]POH 교육감',
#  'PER 박능후[SEP]POH 보건복지부 장관',
#  'ORG 고흥군[SEP]PER 송귀근',
#  'ORG SAO 크라이나[SEP]ORG 크로아티아',
#  'ORG 아메리칸 항공[SEP]DAT 2001년',
#  'ORG 중소벤처기업부[SEP]PER 박영선',
#  'ORG 유신정우회[SEP]ORG 한국국민당',
#  'PER 제임스 본드[SEP]PER 이언 플레밍',
#  'PER 가네코 후미코[SEP]DAT 1926년 7월 23일',
#  'ORG 딴지일보[SEP]PER 김어준',
#  'ORG 수페르리가 엘라다[SEP]POH 그리스',
#  'PER 문재인[SEP]ORG 더불어민주당',
#  'ORG 양주시[SEP]PER 정성호',
#  'ORG FC 모스크바[SEP]ORG 러시아 프리미어리그',
#  'ORG 한나라당[SEP]ORG 통합민주당',
#  'ORG 포항시청[SEP]LOC 경상북도 포항시',
#  'ORG 성균관대[SEP]PER 김창숙',
#  'PER 양예원[SEP]POH 비글커플',
#  'ORG 보성전문학교[SEP]PER 이용익',
#  'PER 문효세자[SEP]PER 의빈 성씨',
#  'PER 클리프 커티스[SEP]LOC 뉴질랜드',
#  'PER 토죠 사토루[SEP]POH 가면라이더',
#  'ORG 통합항공기제작사[SEP]DAT 2006년 2월 20일',
#  'ORG 수원 삼성 블루윙즈[SEP]DAT 2008',
#  'ORG AK플라자[SEP]ORG 백화점',
#  'PER 안 드 브르타뉴[SEP]PER 프랑수아 2세',
#  'ORG 고양시[SEP]NOH 031',
#  'PER 얀 무하[SEP]LOC 슬로바키아',
#  'ORG 참여정부[SEP]PER 노무현',
#  'ORG 미래당[SEP]PER 김소희',
#  'PER 김상경[SEP]ORG 국엔터테인먼트',
#  'PER 안인득[SEP]DAT 1977년 7월',
#  'PER 고토쿠 천황[SEP]POH 사이메이 천황',
#  'PER 박완주[SEP]ORG 더불어민주당',
#  'ORG 고양 원더스[SEP]DAT 2014년',
#  'PER 김종원[SEP]POH 치안국장',
#  'PER 양만춘[SEP]DAT 고구려',
#  'PER 고우다 천황[SEP]PER 후시미 천황',
#  'PER 애슐리 콜[SEP]ORG 아스널',
#  'ORG 노동당[SEP]DAT 1996년',
#  'ORG 민주공화당[SEP]PER 토머스 제퍼슨',
#  'ORG 롯데케미칼[SEP]PER 임병연',
#  'ORG KT&G[SEP]PER 백복인',
#  'PER 주호영[SEP]POH 원내대표',
#  'PER 강민경[SEP]ORG 다비치',
#  'ORG 동강대학교[SEP]PER 이민숙',
#  'ORG 맨체스터 유나이티드 FC[SEP]DAT 2006-07',
#  'PER 레나토 이바라[SEP]ORG Alex Renato Ibarra Mina',
#  'PER 임태경[SEP]DAT 1973년 7월 4일',
#  'ORG 매일유업[SEP]PER 김선희',
#  'PER 루이 16세[SEP]PER 루이 15세',
#  'ORG 아시아나항공[SEP]POH 아시아나클럽',
#  'PER 도미니크 하셰크[SEP]ORG 디트로이트 레드윙스',
#  'ORG 루프트한자[SEP]ORG 스타 얼라이언스',
#  'ORG 랄라블라[SEP]ORG GS리테일',
#  'ORG 중국 공산당[SEP]PER 시진핑',
#  'PER 이문열[SEP]POH 우리들의 일그러진 영웅',
#  'PER 임종식[SEP]POH 교육감',
#  'ORG 통합진보당[SEP]PER 이정희',
#  'ORG 뉴욕 양키스[SEP]DAT 1950',
#  'PER 차은우[SEP]PER 아스트로',
#  'PER 김태술[SEP]ORG 서울 SK 나이츠',
#  'ORG 하포엘 베르셰바[SEP]ORG 리갓 하알',
#  'PER 백종원[SEP]PER 소유진',
#  'ORG 해병대 교육훈련단[SEP]LOC 경상북도 포항시 남구 오천읍',
#  'ORG 피닉스 선스[SEP]POH NBA',
#  'ORG 담양군[SEP]PER 최형식',
#  'ORG 전주 KCC 이지스[SEP]ORG KBL',
#  'PER 김초혜[SEP]PER 조정래',
#  'PER 케텔 마르테[SEP]POH 중견수',
#  'ORG XXX[SEP]PER 김심야',
#  'PER 전덕기[SEP]ORG 감리교',
#  'ORG 열린 우리당[SEP]PER 노무현',
#  'PER 슈체친[SEP]LOC 폴란드',
#  'PER 트리스 스피커[SEP]ORG 클리블랜드 인디언스',
#  'ORG 계원예술대학[SEP]PER 송수근',
#  'ORG 그린 스타디움 고베[SEP]DAT 1988년 3월 6일',
#  'PER 충목왕[SEP]PER 충정왕',
#  'PER 손원일[SEP]POH 독립운동가',
#  'PER 금성대군[SEP]DAT 1426년 5월 5일/음력 3월 28일',
#  'ORG 광양시[SEP]NOH 10개',
#  'ORG 아시아나항공[SEP]ORG HDC현대산업개발',
#  'PER 우에스기 겐신[SEP]DAT 센고쿠 시대',
#  'PER 저스틴 팀버레이크[SEP]PER Justin Timberlake',
#  'ORG 제주특별자치도개발공사[SEP]PER 오경수',
#  'PER 소소업[SEP]PER 울림왕',
#  'ORG 일본 제국 해군[SEP]DAT 1872년',
#  'PER 김종필[SEP]PER 김대중',
#  'ORG 과학기술정보통신부[SEP]ORG 과기정통부',
#  'ORG 화순군[SEP]PER 구충곤',
#  'PER 박일준[SEP]POH 한국동서발전 사장',
#  'PER 벤저민 해리슨[SEP]ORG 공화당',
#  'PER 루이 16세[SEP]PER 마리 앙투아네트',
#  'PER 조지 3세[SEP]PER 프레더릭',
#  'ORG 영남대[SEP]ORG 영남학원',
#  'ORG 팀 호턴스[SEP]LOC 캐나다',
#  'ORG 걸걸중상[SEP]ORG 고구려',
#  'ORG 율촌도서관[SEP]ORG 여수시',
#  'PER 김요협[SEP]DAT 1833년',
#  'PER 인절현비[SEP]PER 이자연',
#  'ORG 람보르기니[SEP]POH 자동차',
#  'PER 트라야누스[SEP]LOC 로마 제국',
#  'ORG 국제해사기구[SEP]ORG IMO',
#  'ORG 가로세로연구소[SEP]PER 김세의',
#  'ORG 전북 현대[SEP]POH 전주월드컵경기장',
#  'ORG 한화 이글스[SEP]POH 유니폼',
#  'PER 장미란[SEP]DAT 1983년 10월 9일',
#  'ORG 순천시[SEP]NOH 281534명',
#  'PER 다이쇼 천황[SEP]POH 쇼와 천황',
#  'PER 류재현[SEP]PER 바이브',
#  'ORG 이화여자전문학교[SEP]ORG 이화학당',
#  'PER 이사벨 1세[SEP]PER 엔리케 4세',
#  'PER 레드벨벳[SEP]PER 아이린',
#  'ORG FC 샬케 04[SEP]ORG 분데스리가',
#  'PER 박재범[SEP]ORG JYP',
#  'PER 쇼무 천황[SEP]POH 몬무 천황',
#  'ORG 펜탁스[SEP]POH 카메라',
#  'ORG AC 밀란[SEP]DAT 2002-03',
#  'ORG 롯데건설[SEP]POH 롯데캐슬',
#  'ORG 전북 현대 모터스[SEP]DAT 2005',
#  'ORG 기획재정부[SEP]PER 홍남기',
#  'PER 찰스 라이엘[SEP]POH 지질학',
#  'PER 쿠사나기 쿄[SEP]PER 야가미 이오리',
#  'ORG 삼성 라이온즈[SEP]DAT 1982년',
#  'ORG 한국팜비오[SEP]PER 남봉길',
#  'PER 박준영[SEP]ORG 국민의당',
#  'PER 황경선[SEP]POH 태권도',
#  'PER 김대중[SEP]DAT 1987년',
#  'ORG 고흥군[SEP]PER 송귀근',
#  'PER 박선용[SEP]ORG 전남 드래곤즈',
#  'PER 정진석[SEP]NOH 16·17·18·20',
#  'PER 미야자키 하야오[SEP]POH 애니메이션 감독',
#  'PER 박희광[SEP]DAT 1901년 2월 15일',
#  'PER 천재노창[SEP]PER 그냥노창',
#  'PER 고연무[SEP]DAT 고구려',
#  'PER 박주선[SEP]ORG 민생당',
#  'ORG 장흥군[SEP]PER 정종순',
#  'ORG 국민건강보험공단[SEP]PER 이사장 김용익',
#  'ORG 문민정부[SEP]PER 김영삼',
#  'ORG FC 서울[SEP]DAT 2016',
#  'ORG 리버풀 FC[SEP]DAT 2005',
#  'ORG 국제 올림픽 위원회[SEP]ORG IOC',
#  'PER 바샤르 알아사드[SEP]PER 아스마 알아사드',
#  'ORG JTBC[SEP]PER 손석희',
#  'PER 김대중[SEP]PER 김홍일',
#  'PER 플로렌스 퓨[SEP]DAT 1996년 1월 3일',
#  'PER 알프 아르슬란[SEP]PER 투으룰 1세',
#  'ORG 담양군[SEP]PER 최형식',
#  'PER 지청천[SEP]PER 이승만',
#  'PER 장제원[SEP]ORG 자유한국당',
#  'ORG 정의개발당[SEP]PER 아흐메트 다우토을루',
#  'PER 이기원[SEP]PER 이봉의',
#  'ORG 봉만대[SEP]POH 영화감독',
#  ...]

# %%
utr.columns
# Out:
# Index(['id', 'sentence', 'subject_word', 'subject_start_idx',
#        'subject_end_idx', 'subject_entity', 'object_word', 'object_start_idx',
#        'object_end_idx', 'object_entity', 'label'],
#       dtype='object')

# %%
for i, u in utr.iterrows():
    print(type(u['subject_start_idx']))
# Out:
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# ...
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>

# %%
def change_sentence(dataset,subject_word_list,obejct_word_list):
    subject_word = []
    subject_start_idx = []
    subject_end_idx = []
    subject_entity = []
    object_word = []
    object_start_idx = []
    object_end_idx = []
    object_entity = []
    sentence = []
    label = []
    for (i, d), s, o in zip(dataset.iterrows(),subject_word_list,obejct_word_list):    
        if d['subject_start_idx'] < d['object_start_idx']:
            subject_start_idx.append(d['subject_start_idx'])
            subject_end_idx.append(d['subject_end_idx'] + len(s) - len(d['subject_word']))
            object_start_idx.append(d['object_start_idx'] + len(s) - len(d['subject_word']))
            object_end_idx.append(d['object_start_idx'] + max(len(d['object_word']), len(o)) -1)
        else:
            object_start_idx.append(d['object_start_idx'])
            object_end_idx.append(d['object_end_idx'] + len(o) - len(d['object_word']))
            subject_start_idx.append(d['subject_start_idx'] + len(o) - len(d['object_word']))
            subject_end_idx.append(d['subject_start_idx'] + max(len(d['subject_word']), len(s)) -1)
        temp = ''
        temp = d['sentence'][:d['subject_start_idx']]+d['sentence'][d['subject_start_idx']:].replace(d['subject_word'],s)
        sentence.append(temp[:d['object_start_idx']]+temp[d['object_start_idx']:].replace(d['object_word'],o))
        subject_word = s
        object_word = o
        subject_entity = None
        object_entity = None 
        label.append('no_relation')
    out_dataset = pd.DataFrame({'id':dataset['id'],'sentence':sentence,\
        'subject_word':subject_word,'subject_start_idx':subject_start_idx,'subject_end_idx':subject_end_idx,'subject_entity':subject_entity,\
        'object_word':object_word,'object_start_idx':object_start_idx,'object_end_idx':object_end_idx,'object_entity':object_entity,\
        'label':label,})
    return out_dataset

# %%
utr.head(5)
# Out:
#    id                                           sentence subject_word  \
# 0   0  〈Something〉는 조지 해리슨이 쓰고 비틀즈가 1969년 앨범 《Abbey R...          비틀즈
# 1   1  호남이 기반인 바른미래당·대안신당·민주평화당이 우여곡절 끝에 합당해 민생당(가칭)으...        민주평화당
# 2   2  K리그2에서 성적 1위를 달리고 있는 광주FC는 지난 26일 한국프로축구연맹으로부터...         광주FC
# 3   3  균일가 생활용품점 (주)아성다이소(대표 박정부)는 코로나19 바이러스로 어려움을 겪...        아성다이소
# 4   4  1967년 프로 야구 드래프트 1순위로 요미우리 자이언츠에게 입단하면서 등번호는 8...    요미우리 자이언츠
#
#    subject_start_idx  subject_end_idx subject_entity object_word  \
# 0                 24               26            ORG      조지 해리슨
# 1                 19               23            ORG        대안신당
# 2                 21               24            ORG    한국프로축구연맹
# 3                 13               17            ORG         박정부
# 4                 22               30            ORG        1967
#
#    object_start_idx  object_end_idx object_entity                      label
# 0                13              18           PER                no_relation
# 1                14              17           ORG                no_relation
# 2                34              41           ORG              org:member_of
# 3                22              24           PER  org:top_members/employees
# 4                 0               3           DAT                no_relation

# %%
change_sentence(utr, utr['subject_entity'], utr['object_entity']).head(5)
# Out:
#    id                                           sentence subject_word  \
# 0   0  〈Something〉는 PER이 쓰고 ORG가 1969년 앨범 《Abbey Road...          ORG
# 1   1  호남이 기반인 바른미래당·ORG·ORG이 우여곡절 끝에 합당해 민생당(가칭)으로 재...          ORG
# 2   2  K리그2에서 성적 1위를 달리고 있는 ORG는 지난 26일 한국프로축구연맹으로부터 ...          ORG
# 3   3  균일가 생활용품점 (주)ORG(대표 박정부)는 코로나19 바이러스로 어려움을 겪고 ...          ORG
# 4   4  DAT년 프로 야구 드래프트 1순위로 ORG에게 입단하면서 등번호는 8번으로 배정되었다.          ORG
#
#    subject_start_idx  subject_end_idx subject_entity object_word  \
# 0                 21               26           None         PER
# 1                 18               23           None         PER
# 2                 21               23           None         PER
# 3                 13               15           None         PER
# 4                 21               30           None         PER
#
#    object_start_idx  object_end_idx object_entity        label
# 0                13              15          None  no_relation
# 1                14              16          None  no_relation
# 2                33              41          None  no_relation
# 3                20              24          None  no_relation
# 4                 0               2          None  no_relation
